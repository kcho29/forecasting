# %%
import os
from dotenv import load_dotenv
from cryptography.hazmat.primitives import serialization
import asyncio
import nest_asyncio
import pandas as pd
import pytz
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
from base.clients.clients import KalshiHttpClient, Environment
import re
from time import sleep
import matplotlib.pyplot as plt
nest_asyncio.apply()


load_dotenv()
env = Environment.PROD
KEYID = os.getenv('KEYID') 
KEYFILE = os.getenv('KEYFILE')
try:
    with open(KEYFILE, "rb") as key_file:
        private_key = serialization.load_pem_private_key(
            key_file.read(),
            password=None  
        )
except FileNotFoundError:
    raise FileNotFoundError(f"Private key file not found at {KEYFILE}")
except Exception as e:
    raise Exception(f"Error loading private key: {str(e)}")

api = KalshiHttpClient(
    key_id=KEYID,
    private_key=private_key,
    environment=env
)

balance = api.get_balance()
print("Balance:", balance)


api.get_exchange_status()['trading_active']
# Out:
# Balance: {'balance': 0, 'portfolio_value': 0, 'updated_ts': 1764040137}
# True

# %%
api.plot_market_candlesticks(ticker="KXPRESNOMFEDCHAIR-25", chart_type="candlestick", days=180)
# Out:
# Plotly is required for plotting. Install with: pip install plotly

# %%
api.get_trades('KXPRESNOMFEDCHAIR-25')
# Out:
# {'cursor': 'EhIKEO_NZGjymlc3nt1GNI6xFNwaDAjH24XJBhCoutqEAw',
#  'trades': [{'count': 2,
#    'created_time': '2025-11-25T02:17:13.991601Z',
#    'no_price': 56,
#    'no_price_dollars': '0.5600',
#    'price': 0.44,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'd31b9909-1c5d-7259-ba0b-d0b13f2da7de',
#    'yes_price': 44,
#    'yes_price_dollars': '0.4400'},
#   {'count': 20,
#    'created_time': '2025-11-25T02:17:13.991601Z',
#    'no_price': 56,
#    'no_price_dollars': '0.5600',
#    'price': 0.44,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '3eac1b09-0dbc-7ff0-8ee3-02bdb400b5a2',
#    'yes_price': 44,
#    'yes_price_dollars': '0.4400'},
#   {'count': 7,
#    'created_time': '2025-11-25T02:17:13.991601Z',
#    'no_price': 56,
#    'no_price_dollars': '0.5600',
#    'price': 0.44,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '3e97d3ce-cc4b-77d8-af56-61c74378257f',
#    'yes_price': 44,
#    'yes_price_dollars': '0.4400'},
#   {'count': 27,
#    'created_time': '2025-11-25T01:57:44.74154Z',
#    'no_price': 55,
#    'no_price_dollars': '0.5500',
#    'price': 0.45,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'c307dc97-ffb9-6b42-81c9-8de4fdbbbb32',
#    'yes_price': 45,
#    'yes_price_dollars': '0.4500'},
#   {'count': 62,
#    'created_time': '2025-11-25T01:57:44.74154Z',
#    'no_price': 54,
#    'no_price_dollars': '0.5400',
#    'price': 0.46,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '8c51bb66-b54a-604a-8bd6-0ba3a5d76833',
#    'yes_price': 46,
#    'yes_price_dollars': '0.4600'},
#   {'count': 31,
#    'created_time': '2025-11-25T01:57:44.74154Z',
#    'no_price': 55,
#    'no_price_dollars': '0.5500',
#    'price': 0.45,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '82d9d814-13ad-6132-917d-945016a85274',
#    'yes_price': 45,
#    'yes_price_dollars': '0.4500'},
#   {'count': 32,
#    'created_time': '2025-11-25T01:57:44.74154Z',
#    'no_price': 55,
#    'no_price_dollars': '0.5500',
#    'price': 0.45,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '712f02d3-53ff-6041-a883-84c6ca64474b',
#    'yes_price': 45,
#    'yes_price_dollars': '0.4500'},
#   {'count': 18,
#    'created_time': '2025-11-25T01:57:44.74154Z',
#    'no_price': 55,
#    'no_price_dollars': '0.5500',
#    'price': 0.45,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '192abeba-4a2c-660c-b75c-374d6a42d1aa',
#    'yes_price': 45,
#    'yes_price_dollars': '0.4500'},
#   {'count': 42,
#    'created_time': '2025-11-25T01:57:44.74154Z',
#    'no_price': 55,
#    'no_price_dollars': '0.5500',
#    'price': 0.45,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '0b7db0ea-050a-6487-96e4-cc5a8426d750',
#    'yes_price': 45,
#    'yes_price_dollars': '0.4500'},
#   {'count': 35,
#    'created_time': '2025-11-25T01:03:44.161693Z',
#    'no_price': 57,
#    'no_price_dollars': '0.5700',
#    'price': 0.43,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'c6380788-a01c-7708-6f9e-e34cd14553f6',
#    'yes_price': 43,
#    'yes_price_dollars': '0.4300'},
#   {'count': 4,
#    'created_time': '2025-11-25T01:03:44.161693Z',
#    'no_price': 56,
#    'no_price_dollars': '0.5600',
#    'price': 0.44,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'c282c46f-ed70-7185-5e91-ab8895c6a15a',
#    'yes_price': 44,
#    'yes_price_dollars': '0.4400'},
#   {'count': 3,
#    'created_time': '2025-11-25T01:03:44.161693Z',
#    'no_price': 56,
#    'no_price_dollars': '0.5600',
#    'price': 0.44,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '49a32fd8-e0fc-7a96-79f9-81788fd01da5',
#    'yes_price': 44,
#    'yes_price_dollars': '0.4400'},
#   {'count': 27,
#    'created_time': '2025-11-25T00:39:31.758752Z',
#    'no_price': 56,
#    'no_price_dollars': '0.5600',
#    'price': 0.44,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'e7b2d582-f294-7a6f-8e66-ff8352626acc',
#    'yes_price': 44,
#    'yes_price_dollars': '0.4400'},
#   {'count': 973,
#    'created_time': '2025-11-25T00:39:31.758752Z',
#    'no_price': 56,
#    'no_price_dollars': '0.5600',
#    'price': 0.44,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '25b48a71-f1c2-7b11-91ab-3abdc73c8cef',
#    'yes_price': 44,
#    'yes_price_dollars': '0.4400'},
#   {'count': 27,
#    'created_time': '2025-11-25T00:39:31.7566Z',
#    'no_price': 56,
#    'no_price_dollars': '0.5600',
#    'price': 0.44,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'e15b363c-496a-4531-6d47-70d3dea42dab',
#    'yes_price': 44,
#    'yes_price_dollars': '0.4400'},
#   {'count': 3,
#    'created_time': '2025-11-25T00:39:31.7566Z',
#    'no_price': 56,
#    'no_price_dollars': '0.5600',
#    'price': 0.44,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '893a96b2-57df-4244-5b27-6a944a3fb2a5',
#    'yes_price': 44,
#    'yes_price_dollars': '0.4400'},
#   {'count': 142,
#    'created_time': '2025-11-25T00:39:09.378412Z',
#    'no_price': 56,
#    'no_price_dollars': '0.5600',
#    'price': 0.44,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '95420bf0-7210-6891-6cf0-eafeba97a53f',
#    'yes_price': 44,
#    'yes_price_dollars': '0.4400'},
#   {'count': 32,
#    'created_time': '2025-11-25T00:39:09.378412Z',
#    'no_price': 56,
#    'no_price_dollars': '0.5600',
#    'price': 0.44,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '645fd5f6-8788-6a50-421e-9f80d50480ff',
#    'yes_price': 44,
#    'yes_price_dollars': '0.4400'},
#   {'count': 13,
#    'created_time': '2025-11-25T00:39:09.378412Z',
#    'no_price': 56,
#    'no_price_dollars': '0.5600',
#    'price': 0.44,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '29829057-1463-6b50-4d2f-a27b61903681',
#    'yes_price': 44,
#    'yes_price_dollars': '0.4400'},
#   {'count': 50,
#    'created_time': '2025-11-24T23:33:40.531403Z',
#    'no_price': 55,
#    'no_price_dollars': '0.5500',
#    'price': 0.45,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '4e31915f-cd40-5ec4-6a4b-d3c069c933f6',
#    'yes_price': 45,
#    'yes_price_dollars': '0.4500'},
#   {'count': 1000,
#    'created_time': '2025-11-24T23:33:36.075937Z',
#    'no_price': 55,
#    'no_price_dollars': '0.5500',
#    'price': 0.45,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '5779d30b-bde7-6bd1-2db7-617695a64e18',
#    'yes_price': 45,
#    'yes_price_dollars': '0.4500'},
#   {'count': 278,
#    'created_time': '2025-11-24T23:33:36.075937Z',
#    'no_price': 55,
#    'no_price_dollars': '0.5500',
#    'price': 0.45,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '37465611-111f-6831-2883-79c4a89cb4b0',
#    'yes_price': 45,
#    'yes_price_dollars': '0.4500'},
#   {'count': 41,
#    'created_time': '2025-11-24T23:26:20.919046Z',
#    'no_price': 54,
#    'no_price_dollars': '0.5400',
#    'price': 0.46,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '5323bb1d-ed2a-6182-b3d2-7c9af8b11ccf',
#    'yes_price': 46,
#    'yes_price_dollars': '0.4600'},
#   {'count': 20,
#    'created_time': '2025-11-24T23:10:14.243754Z',
#    'no_price': 54,
#    'no_price_dollars': '0.5400',
#    'price': 0.46,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '690d8aa5-ba3e-6d4a-7dbe-a098b98938d3',
#    'yes_price': 46,
#    'yes_price_dollars': '0.4600'},
#   {'count': 1,
#    'created_time': '2025-11-24T22:02:11.425197Z',
#    'no_price': 54,
#    'no_price_dollars': '0.5400',
#    'price': 0.46,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'a19d7c0d-3ec2-55c6-d178-d18eb43fc5cf',
#    'yes_price': 46,
#    'yes_price_dollars': '0.4600'},
#   {'count': 9,
#    'created_time': '2025-11-24T21:23:32.047573Z',
#    'no_price': 55,
#    'no_price_dollars': '0.5500',
#    'price': 0.45,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'a53e2ebc-ad28-40e2-3439-43bb8747320d',
#    'yes_price': 45,
#    'yes_price_dollars': '0.4500'},
#   {'count': 68,
#    'created_time': '2025-11-24T21:03:28.040891Z',
#    'no_price': 54,
#    'no_price_dollars': '0.5400',
#    'price': 0.46,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'f83cdd14-8d95-70b5-9ce1-11d4f000ce72',
#    'yes_price': 46,
#    'yes_price_dollars': '0.4600'},
#   {'count': 1000,
#    'created_time': '2025-11-24T21:03:28.040891Z',
#    'no_price': 54,
#    'no_price_dollars': '0.5400',
#    'price': 0.46,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '67e54f5f-e015-7b19-b765-68b5272f8a32',
#    'yes_price': 46,
#    'yes_price_dollars': '0.4600'},
#   {'count': 69,
#    'created_time': '2025-11-24T21:03:28.040891Z',
#    'no_price': 54,
#    'no_price_dollars': '0.5400',
#    'price': 0.46,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '4df4e601-c20d-7c42-8bca-96ea1d219ccb',
#    'yes_price': 46,
#    'yes_price_dollars': '0.4600'},
#   {'count': 255,
#    'created_time': '2025-11-24T21:03:28.040891Z',
#    'no_price': 54,
#    'no_price_dollars': '0.5400',
#    'price': 0.46,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '315ace92-1a09-7087-8188-6768bc1b2e92',
#    'yes_price': 46,
#    'yes_price_dollars': '0.4600'},
#   {'count': 319,
#    'created_time': '2025-11-24T20:54:22.864884Z',
#    'no_price': 54,
#    'no_price_dollars': '0.5400',
#    'price': 0.46,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'a6a0e1eb-141c-546d-b88c-c06c1d0a0394',
#    'yes_price': 46,
#    'yes_price_dollars': '0.4600'},
#   {'count': 33,
#    'created_time': '2025-11-24T20:54:22.864884Z',
#    'no_price': 54,
#    'no_price_dollars': '0.5400',
#    'price': 0.46,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '7d968f60-dc6d-54eb-b730-88cbe522209f',
#    'yes_price': 46,
#    'yes_price_dollars': '0.4600'},
#   {'count': 1648,
#    'created_time': '2025-11-24T20:54:22.864884Z',
#    'no_price': 54,
#    'no_price_dollars': '0.5400',
#    'price': 0.46,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '31077ab7-36b1-5983-ba63-46da39fd2eba',
#    'yes_price': 46,
#    'yes_price_dollars': '0.4600'},
#   {'count': 28,
#    'created_time': '2025-11-24T20:51:27.330896Z',
#    'no_price': 54,
#    'no_price_dollars': '0.5400',
#    'price': 0.46,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '47d2a0d0-8fc4-56c0-d75e-70d972dff4d2',
#    'yes_price': 46,
#    'yes_price_dollars': '0.4600'},
#   {'count': 1436,
#    'created_time': '2025-11-24T20:16:48.202379Z',
#    'no_price': 53,
#    'no_price_dollars': '0.5300',
#    'price': 0.47,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '7520c57d-3979-59d2-3754-79162d8815c7',
#    'yes_price': 47,
#    'yes_price_dollars': '0.4700'},
#   {'count': 100,
#    'created_time': '2025-11-24T19:43:09.357805Z',
#    'no_price': 54,
#    'no_price_dollars': '0.5400',
#    'price': 0.46,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '2ed9a681-1bf2-4814-71b5-3b5c93e0982d',
#    'yes_price': 46,
#    'yes_price_dollars': '0.4600'},
#   {'count': 51,
#    'created_time': '2025-11-24T19:42:43.369276Z',
#    'no_price': 53,
#    'no_price_dollars': '0.5300',
#    'price': 0.47,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'd519088b-29e1-5816-92ab-10cc14ffa297',
#    'yes_price': 47,
#    'yes_price_dollars': '0.4700'},
#   {'count': 1000,
#    'created_time': '2025-11-24T19:19:01.007638Z',
#    'no_price': 53,
#    'no_price_dollars': '0.5300',
#    'price': 0.47,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'f0302176-4fb7-4575-7cbe-850e797e9811',
#    'yes_price': 47,
#    'yes_price_dollars': '0.4700'},
#   {'count': 300,
#    'created_time': '2025-11-24T19:19:01.007638Z',
#    'no_price': 53,
#    'no_price_dollars': '0.5300',
#    'price': 0.47,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '63f6d4df-14d5-4058-6d8f-3a72992103be',
#    'yes_price': 47,
#    'yes_price_dollars': '0.4700'},
#   {'count': 53,
#    'created_time': '2025-11-24T18:31:42.952756Z',
#    'no_price': 53,
#    'no_price_dollars': '0.5300',
#    'price': 0.47,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'c3ac4f0c-e6d5-7e9c-0fd6-26f50dc1df8a',
#    'yes_price': 47,
#    'yes_price_dollars': '0.4700'},
#   {'count': 10,
#    'created_time': '2025-11-24T17:58:21.670042Z',
#    'no_price': 53,
#    'no_price_dollars': '0.5300',
#    'price': 0.47,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '5a2c080c-3449-768c-7fd0-89b3eb398732',
#    'yes_price': 47,
#    'yes_price_dollars': '0.4700'},
#   {'count': 110,
#    'created_time': '2025-11-24T17:00:38.606675Z',
#    'no_price': 53,
#    'no_price_dollars': '0.5300',
#    'price': 0.47,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'c1f4639b-f06b-5a1f-d1db-cd96700f8463',
#    'yes_price': 47,
#    'yes_price_dollars': '0.4700'},
#   {'count': 27,
#    'created_time': '2025-11-24T17:00:38.606675Z',
#    'no_price': 53,
#    'no_price_dollars': '0.5300',
#    'price': 0.47,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '9183f398-b8d9-540d-f4ba-1d167d2139ce',
#    'yes_price': 47,
#    'yes_price_dollars': '0.4700'},
#   {'count': 200,
#    'created_time': '2025-11-24T16:51:32.470467Z',
#    'no_price': 53,
#    'no_price_dollars': '0.5300',
#    'price': 0.47,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'cb1da85a-a7e5-6c81-e940-5cdd67b1ef5a',
#    'yes_price': 47,
#    'yes_price_dollars': '0.4700'},
#   {'count': 118,
#    'created_time': '2025-11-24T13:51:09.989042Z',
#    'no_price': 53,
#    'no_price_dollars': '0.5300',
#    'price': 0.47,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '69beadef-4575-450d-7746-d60fb2e8a436',
#    'yes_price': 47,
#    'yes_price_dollars': '0.4700'},
#   {'count': 340,
#    'created_time': '2025-11-24T13:51:06.639643Z',
#    'no_price': 53,
#    'no_price_dollars': '0.5300',
#    'price': 0.47,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '80d5a810-590c-724e-6176-7ffadd15c94b',
#    'yes_price': 47,
#    'yes_price_dollars': '0.4700'},
#   {'count': 1000,
#    'created_time': '2025-11-24T13:51:06.639643Z',
#    'no_price': 53,
#    'no_price_dollars': '0.5300',
#    'price': 0.47,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '3642157d-c9d4-743c-5a19-789ca6f083c7',
#    'yes_price': 47,
#    'yes_price_dollars': '0.4700'},
#   {'count': 25,
#    'created_time': '2025-11-24T07:09:08.650651Z',
#    'no_price': 53,
#    'no_price_dollars': '0.5300',
#    'price': 0.47,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '0dfa4511-fc68-6065-3f81-c9b67946547a',
#    'yes_price': 47,
#    'yes_price_dollars': '0.4700'},
#   {'count': 247,
#    'created_time': '2025-11-24T04:28:23.282761Z',
#    'no_price': 52,
#    'no_price_dollars': '0.5200',
#    'price': 0.48,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '30dc8d30-adf9-4880-cdc6-adb0f46c5f5a',
#    'yes_price': 48,
#    'yes_price_dollars': '0.4800'},
#   {'count': 29,
#    'created_time': '2025-11-24T03:44:41.706685Z',
#    'no_price': 51,
#    'no_price_dollars': '0.5100',
#    'price': 0.49,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '7dc19602-de7d-479d-fa07-579a6c9c9bbc',
#    'yes_price': 49,
#    'yes_price_dollars': '0.4900'},
#   {'count': 2,
#    'created_time': '2025-11-24T02:52:09.011245Z',
#    'no_price': 52,
#    'no_price_dollars': '0.5200',
#    'price': 0.48,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '95bc0ffc-0345-5004-fdc6-0719c0d04c4a',
#    'yes_price': 48,
#    'yes_price_dollars': '0.4800'},
#   {'count': 41,
#    'created_time': '2025-11-24T01:25:09.514654Z',
#    'no_price': 50,
#    'no_price_dollars': '0.5000',
#    'price': 0.5,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'd40173c4-6c0b-5ba5-de7b-ea193ceaa011',
#    'yes_price': 50,
#    'yes_price_dollars': '0.5000'},
#   {'count': 1000,
#    'created_time': '2025-11-24T01:25:09.514654Z',
#    'no_price': 50,
#    'no_price_dollars': '0.5000',
#    'price': 0.5,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '86fce817-a20a-58fd-dd16-933479dadea2',
#    'yes_price': 50,
#    'yes_price_dollars': '0.5000'},
#   {'count': 5,
#    'created_time': '2025-11-24T01:25:09.514654Z',
#    'no_price': 51,
#    'no_price_dollars': '0.5100',
#    'price': 0.49,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '6b0c1847-dcc8-5a8a-fae3-4fa6bab4998a',
#    'yes_price': 49,
#    'yes_price_dollars': '0.4900'},
#   {'count': 500,
#    'created_time': '2025-11-24T01:25:09.514654Z',
#    'no_price': 50,
#    'no_price_dollars': '0.5000',
#    'price': 0.5,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '4fb318dd-1df5-514a-ea68-7a4064b3b397',
#    'yes_price': 50,
#    'yes_price_dollars': '0.5000'},
#   {'count': 18,
#    'created_time': '2025-11-23T22:40:33.521213Z',
#    'no_price': 50,
#    'no_price_dollars': '0.5000',
#    'price': 0.5,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '8f5dcab7-cb84-596a-0c60-664e2760a0a6',
#    'yes_price': 50,
#    'yes_price_dollars': '0.5000'},
#   {'count': 94,
#    'created_time': '2025-11-23T22:40:33.521213Z',
#    'no_price': 50,
#    'no_price_dollars': '0.5000',
#    'price': 0.5,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '68c82798-4506-5194-3ba8-52545ba7673b',
#    'yes_price': 50,
#    'yes_price_dollars': '0.5000'},
#   {'count': 8,
#    'created_time': '2025-11-23T22:39:38.427718Z',
#    'no_price': 50,
#    'no_price_dollars': '0.5000',
#    'price': 0.5,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'f33f3b63-d926-5c5c-20e9-fa78e73b83a6',
#    'yes_price': 50,
#    'yes_price_dollars': '0.5000'},
#   {'count': 305,
#    'created_time': '2025-11-23T22:39:38.427718Z',
#    'no_price': 50,
#    'no_price_dollars': '0.5000',
#    'price': 0.5,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'eda5a647-2bc8-5fe6-17b2-86818c19d872',
#    'yes_price': 50,
#    'yes_price_dollars': '0.5000'},
#   {'count': 88,
#    'created_time': '2025-11-23T22:39:38.427718Z',
#    'no_price': 50,
#    'no_price_dollars': '0.5000',
#    'price': 0.5,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'dc37621e-6607-5ea7-1309-83c0395490c2',
#    'yes_price': 50,
#    'yes_price_dollars': '0.5000'},
#   {'count': 175,
#    'created_time': '2025-11-23T22:39:38.427718Z',
#    'no_price': 50,
#    'no_price_dollars': '0.5000',
#    'price': 0.5,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '3659ee7a-d1c1-5d0f-0bb6-c6510a705c8c',
#    'yes_price': 50,
#    'yes_price_dollars': '0.5000'},
#   {'count': 116,
#    'created_time': '2025-11-23T22:39:38.427718Z',
#    'no_price': 50,
#    'no_price_dollars': '0.5000',
#    'price': 0.5,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '0482ad24-8f45-5a1d-2e2e-4f0b3ba0b14e',
#    'yes_price': 50,
#    'yes_price_dollars': '0.5000'},
#   {'count': 318,
#    'created_time': '2025-11-23T22:01:54.541579Z',
#    'no_price': 50,
#    'no_price_dollars': '0.5000',
#    'price': 0.5,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '75c8c4d4-4915-47d5-808c-6710f681b30a',
#    'yes_price': 50,
#    'yes_price_dollars': '0.5000'},
#   {'count': 112,
#    'created_time': '2025-11-23T22:01:54.541579Z',
#    'no_price': 49,
#    'no_price_dollars': '0.4900',
#    'price': 0.51,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '5636a3ab-4d5a-4429-8719-b229ab230c61',
#    'yes_price': 51,
#    'yes_price_dollars': '0.5100'},
#   {'count': 105,
#    'created_time': '2025-11-23T21:50:36.029511Z',
#    'no_price': 49,
#    'no_price_dollars': '0.4900',
#    'price': 0.51,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'af468cb1-0ed2-69ca-c9a8-fec72602a6a0',
#    'yes_price': 51,
#    'yes_price_dollars': '0.5100'},
#   {'count': 1000,
#    'created_time': '2025-11-23T21:50:36.029511Z',
#    'no_price': 49,
#    'no_price_dollars': '0.4900',
#    'price': 0.51,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '8a99f432-eacb-6dfb-dd00-f22045bab7df',
#    'yes_price': 51,
#    'yes_price_dollars': '0.5100'},
#   {'count': 200,
#    'created_time': '2025-11-23T21:50:36.029511Z',
#    'no_price': 49,
#    'no_price_dollars': '0.4900',
#    'price': 0.51,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '416ea3bc-effc-6488-f9a8-72d7146b0359',
#    'yes_price': 51,
#    'yes_price_dollars': '0.5100'},
#   {'count': 445,
#    'created_time': '2025-11-23T21:50:36.029511Z',
#    'no_price': 49,
#    'no_price_dollars': '0.4900',
#    'price': 0.51,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '29f8bebe-8577-6b6c-d972-4f6f226ad5a0',
#    'yes_price': 51,
#    'yes_price_dollars': '0.5100'},
#   {'count': 69,
#    'created_time': '2025-11-23T18:50:48.147329Z',
#    'no_price': 48,
#    'no_price_dollars': '0.4800',
#    'price': 0.52,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'f49dd7af-5092-5f50-3a72-6994e93c9486',
#    'yes_price': 52,
#    'yes_price_dollars': '0.5200'},
#   {'count': 42,
#    'created_time': '2025-11-23T18:50:48.147329Z',
#    'no_price': 48,
#    'no_price_dollars': '0.4800',
#    'price': 0.52,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'f340aec6-3671-58e4-30e1-6182b01d27d9',
#    'yes_price': 52,
#    'yes_price_dollars': '0.5200'},
#   {'count': 139,
#    'created_time': '2025-11-23T18:16:09.302826Z',
#    'no_price': 47,
#    'no_price_dollars': '0.4700',
#    'price': 0.53,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '1c33b527-4797-6379-1ba5-03e68eb5db88',
#    'yes_price': 53,
#    'yes_price_dollars': '0.5300'},
#   {'count': 100,
#    'created_time': '2025-11-23T16:53:37.083475Z',
#    'no_price': 48,
#    'no_price_dollars': '0.4800',
#    'price': 0.52,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'f8a3407c-0b66-7795-99f8-98400a5a9942',
#    'yes_price': 52,
#    'yes_price_dollars': '0.5200'},
#   {'count': 201,
#    'created_time': '2025-11-23T09:06:44.872439Z',
#    'no_price': 48,
#    'no_price_dollars': '0.4800',
#    'price': 0.52,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '6ecc3156-a270-4e8e-1ce2-f4ce6e3afaf8',
#    'yes_price': 52,
#    'yes_price_dollars': '0.5200'},
#   {'count': 3,
#    'created_time': '2025-11-23T07:06:14.567642Z',
#    'no_price': 47,
#    'no_price_dollars': '0.4700',
#    'price': 0.53,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'b5d92260-210b-75dd-c0e6-e5e179fb0f64',
#    'yes_price': 53,
#    'yes_price_dollars': '0.5300'},
#   {'count': 303,
#    'created_time': '2025-11-23T05:38:06.198532Z',
#    'no_price': 47,
#    'no_price_dollars': '0.4700',
#    'price': 0.53,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '67bf134f-3893-4c93-2352-217faa9e67f7',
#    'yes_price': 53,
#    'yes_price_dollars': '0.5300'},
#   {'count': 491,
#    'created_time': '2025-11-23T05:38:06.198532Z',
#    'no_price': 47,
#    'no_price_dollars': '0.4700',
#    'price': 0.53,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '58b53b21-cc3a-4c0c-2ba9-c792163b6fa0',
#    'yes_price': 53,
#    'yes_price_dollars': '0.5300'},
#   {'count': 188,
#    'created_time': '2025-11-23T05:38:06.198532Z',
#    'no_price': 47,
#    'no_price_dollars': '0.4700',
#    'price': 0.53,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '05940b0c-eb2e-44e1-3104-f0f009e0ddf1',
#    'yes_price': 53,
#    'yes_price_dollars': '0.5300'},
#   {'count': 197,
#    'created_time': '2025-11-23T05:37:40.38626Z',
#    'no_price': 47,
#    'no_price_dollars': '0.4700',
#    'price': 0.53,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'bb128ef1-203b-5933-716e-6f136b22f677',
#    'yes_price': 53,
#    'yes_price_dollars': '0.5300'},
#   {'count': 5,
#    'created_time': '2025-11-23T05:27:52.657952Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'f519537d-ce6e-43dc-37fe-f6898dcc2027',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 17,
#    'created_time': '2025-11-23T05:27:52.657952Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'f117ccff-d0ae-4c79-1b4c-1bc27d6d371c',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 27,
#    'created_time': '2025-11-23T05:27:52.657952Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'ccdb5e1e-7ac2-49fe-2ebe-e114dc47ba4f',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 5,
#    'created_time': '2025-11-23T05:27:52.657952Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'aa8dfbd1-6cba-48db-2871-4bf5b401ace4',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 5,
#    'created_time': '2025-11-23T05:27:52.657952Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '896289b5-76ce-44ae-047e-bd985d1fa582',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 105,
#    'created_time': '2025-11-23T05:27:52.657952Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '7c0f14e2-0672-49a8-3126-3fe15fe7a799',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 5,
#    'created_time': '2025-11-23T05:27:52.657952Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '7198a973-b502-44c6-2e94-0ac1867cc236',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 5,
#    'created_time': '2025-11-23T05:27:52.657952Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '312c3f48-04e2-4882-2f79-61322cb7c7e0',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 97,
#    'created_time': '2025-11-23T05:27:52.657952Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '15a91b69-8d53-4e37-1873-24d0b7ae415e',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 105,
#    'created_time': '2025-11-23T05:27:52.657952Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '0d058b93-4003-4616-2700-f7aeaba999e6',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 8,
#    'created_time': '2025-11-23T04:51:54.37955Z',
#    'no_price': 45,
#    'no_price_dollars': '0.4500',
#    'price': 0.55,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'c07726af-7dfe-523f-8bfd-20af98973cc0',
#    'yes_price': 55,
#    'yes_price_dollars': '0.5500'},
#   {'count': 2,
#    'created_time': '2025-11-23T03:24:58.266121Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '73390cea-db2b-7ee6-0d5b-de4285f213a5',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 649,
#    'created_time': '2025-11-23T01:28:36.039785Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '07fd16ce-0223-7eae-ddff-afa0b1ff3839',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 28,
#    'created_time': '2025-11-22T22:44:06.107292Z',
#    'no_price': 45,
#    'no_price_dollars': '0.4500',
#    'price': 0.55,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '3067f6db-2f6e-76ab-41ef-1b393ca43ec0',
#    'yes_price': 55,
#    'yes_price_dollars': '0.5500'},
#   {'count': 10,
#    'created_time': '2025-11-22T22:23:55.411968Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'a53e4c76-2887-4826-895e-909e4509fd11',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 350,
#    'created_time': '2025-11-22T21:58:33.378387Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '3ce760d5-ef63-7e92-f28a-caa3d4f050a1',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 15,
#    'created_time': '2025-11-22T20:39:32.185619Z',
#    'no_price': 45,
#    'no_price_dollars': '0.4500',
#    'price': 0.55,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '1fab0512-70c2-5ae7-036d-b4776b7e7334',
#    'yes_price': 55,
#    'yes_price_dollars': '0.5500'},
#   {'count': 2,
#    'created_time': '2025-11-22T18:52:23.835495Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '961f3846-2b0b-667e-ca08-1549cf959ffd',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 200,
#    'created_time': '2025-11-22T15:18:56.90503Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '2a084825-a18b-4522-6a29-d26dfce66a61',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 220,
#    'created_time': '2025-11-22T12:58:04.081566Z',
#    'no_price': 45,
#    'no_price_dollars': '0.4500',
#    'price': 0.55,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '03213d8e-a05e-7657-fb3e-dc3b374c7a40',
#    'yes_price': 55,
#    'yes_price_dollars': '0.5500'},
#   {'count': 6,
#    'created_time': '2025-11-22T12:55:28.904162Z',
#    'no_price': 46,
#    'no_price_dollars': '0.4600',
#    'price': 0.54,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '89c2e18a-a87f-5292-6396-30b717593279',
#    'yes_price': 54,
#    'yes_price_dollars': '0.5400'},
#   {'count': 5,
#    'created_time': '2025-11-22T08:01:11.815177Z',
#    'no_price': 45,
#    'no_price_dollars': '0.4500',
#    'price': 0.55,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'efcd6468-f29a-5737-9edd-46348eb114dc',
#    'yes_price': 55,
#    'yes_price_dollars': '0.5500'}]}

# %%
api.get_markets(series_ticker='KXTRUMPMENTION')
# Out:
# {'cursor': 'CgsIl6HuxwYQsKyJIBIaS1hUUlVNUE1FTlRJT04tMjVPQ1QyNy1PSUw',
#  'markets': [{'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Windmill'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 98,
#    'last_price_dollars': '0.9800',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Windmill',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 8636,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 34,
#    'previous_price_dollars': '0.3400',
#    'previous_yes_ask': 34,
#    'previous_yes_ask_dollars': '0.3400',
#    'previous_yes_bid': 29,
#    'previous_yes_bid_dollars': '0.2900',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Windmill as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-WIND',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 9838,
#    'volume_24h': 8617,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Windmill'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Trump'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 2,
#    'last_price_dollars': '0.0200',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Trump',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 13435,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 27,
#    'previous_price_dollars': '0.2700',
#    'previous_yes_ask': 35,
#    'previous_yes_ask_dollars': '0.3500',
#    'previous_yes_bid': 27,
#    'previous_yes_bid_dollars': '0.2700',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Trump as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-TRUM',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 16318,
#    'volume_24h': 15505,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Trump'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Tax'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 98,
#    'last_price_dollars': '0.9800',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Tax',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 7242,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 79,
#    'previous_price_dollars': '0.7900',
#    'previous_yes_ask': 85,
#    'previous_yes_ask_dollars': '0.8500',
#    'previous_yes_bid': 79,
#    'previous_yes_bid_dollars': '0.7900',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Tax as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-TAX',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 8366,
#    'volume_24h': 7052,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Tax'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Radical Left'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 98,
#    'last_price_dollars': '0.9800',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Radical Left',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 4580,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 86,
#    'previous_price_dollars': '0.8600',
#    'previous_yes_ask': 85,
#    'previous_yes_ask_dollars': '0.8500',
#    'previous_yes_bid': 56,
#    'previous_yes_bid_dollars': '0.5600',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Radical Left as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-RADI',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 5764,
#    'volume_24h': 4777,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Radical Left'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Invest / Investment'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 2,
#    'last_price_dollars': '0.0200',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Invest / Investment',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 8260,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 38,
#    'previous_price_dollars': '0.3800',
#    'previous_yes_ask': 40,
#    'previous_yes_ask_dollars': '0.4000',
#    'previous_yes_bid': 34,
#    'previous_yes_bid_dollars': '0.3400',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Invest / Investment as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-INVE',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 9033,
#    'volume_24h': 8724,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Invest / Investment'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Inflation'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 1,
#    'last_price_dollars': '0.0100',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Inflation',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 5971,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 42,
#    'previous_price_dollars': '0.4200',
#    'previous_yes_ask': 42,
#    'previous_yes_ask_dollars': '0.4200',
#    'previous_yes_bid': 34,
#    'previous_yes_bid_dollars': '0.3400',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Inflation as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-INFL',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 7808,
#    'volume_24h': 7117,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Inflation'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Illegal Alien'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 99,
#    'last_price_dollars': '0.9900',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Illegal Alien',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 7174,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 50,
#    'previous_price_dollars': '0.5000',
#    'previous_yes_ask': 59,
#    'previous_yes_ask_dollars': '0.5900',
#    'previous_yes_bid': 56,
#    'previous_yes_bid_dollars': '0.5600',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Illegal Alien as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-ILLE',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 8260,
#    'volume_24h': 7501,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Illegal Alien'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Hottest'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 2,
#    'last_price_dollars': '0.0200',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Hottest',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 3365,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 52,
#    'previous_price_dollars': '0.5200',
#    'previous_yes_ask': 52,
#    'previous_yes_ask_dollars': '0.5200',
#    'previous_yes_bid': 34,
#    'previous_yes_bid_dollars': '0.3400',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Hottest as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-HOTT',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 4437,
#    'volume_24h': 4234,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Hottest'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Energy'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 98,
#    'last_price_dollars': '0.9800',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Energy',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 4435,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 80,
#    'previous_price_dollars': '0.8000',
#    'previous_yes_ask': 83,
#    'previous_yes_ask_dollars': '0.8300',
#    'previous_yes_bid': 80,
#    'previous_yes_bid_dollars': '0.8000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Energy as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-ENER',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 5110,
#    'volume_24h': 3339,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Energy'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Drug'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 97,
#    'last_price_dollars': '0.9700',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Drug',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 8733,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 64,
#    'previous_price_dollars': '0.6400',
#    'previous_yes_ask': 65,
#    'previous_yes_ask_dollars': '0.6500',
#    'previous_yes_bid': 57,
#    'previous_yes_bid_dollars': '0.5700',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Drug as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-DRUG',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 9732,
#    'volume_24h': 8892,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Drug'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Disaster'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 97,
#    'last_price_dollars': '0.9700',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Disaster',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 5724,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 65,
#    'previous_price_dollars': '0.6500',
#    'previous_yes_ask': 64,
#    'previous_yes_ask_dollars': '0.6400',
#    'previous_yes_bid': 56,
#    'previous_yes_bid_dollars': '0.5600',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Disaster as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-DISA',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 6514,
#    'volume_24h': 6171,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Disaster'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Democrat'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 98,
#    'last_price_dollars': '0.9800',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Democrat',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 6428,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 87,
#    'previous_price_dollars': '0.8700',
#    'previous_yes_ask': 86,
#    'previous_yes_ask_dollars': '0.8600',
#    'previous_yes_bid': 78,
#    'previous_yes_bid_dollars': '0.7800',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Democrat as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-DEMO',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 8161,
#    'volume_24h': 6595,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Democrat'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Corrupt'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 98,
#    'last_price_dollars': '0.9800',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Corrupt',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 4186,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 63,
#    'previous_price_dollars': '0.6300',
#    'previous_yes_ask': 63,
#    'previous_yes_ask_dollars': '0.6300',
#    'previous_yes_bid': 55,
#    'previous_yes_bid_dollars': '0.5500',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Corrupt as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-CORR',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 6018,
#    'volume_24h': 4542,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Corrupt'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Cheat / Cheater / Cheated'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 1,
#    'last_price_dollars': '0.0100',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Cheat / Cheater / Cheated',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 27138,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 30,
#    'previous_price_dollars': '0.3000',
#    'previous_yes_ask': 33,
#    'previous_yes_ask_dollars': '0.3300',
#    'previous_yes_bid': 25,
#    'previous_yes_bid_dollars': '0.2500',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Cheat / Cheater / Cheated as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-CHEA',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 36610,
#    'volume_24h': 36132,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Cheat / Cheater / Cheated'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Border'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 98,
#    'last_price_dollars': '0.9800',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Border',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 7456,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 70,
#    'previous_price_dollars': '0.7000',
#    'previous_yes_ask': 70,
#    'previous_yes_ask_dollars': '0.7000',
#    'previous_yes_bid': 61,
#    'previous_yes_bid_dollars': '0.6100',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Border as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-BORD',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 9335,
#    'volume_24h': 6471,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Border'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Biden'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 3,
#    'last_price_dollars': '0.0300',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Biden',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 30723,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 73,
#    'previous_price_dollars': '0.7300',
#    'previous_yes_ask': 75,
#    'previous_yes_ask_dollars': '0.7500',
#    'previous_yes_bid': 69,
#    'previous_yes_bid_dollars': '0.6900',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Biden as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-BIDE',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 40075,
#    'volume_24h': 39719,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Biden'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Bedminster'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 2,
#    'last_price_dollars': '0.0200',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Bedminster',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 2364,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 30,
#    'previous_price_dollars': '0.3000',
#    'previous_yes_ask': 32,
#    'previous_yes_ask_dollars': '0.3200',
#    'previous_yes_bid': 22,
#    'previous_yes_bid_dollars': '0.2200',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Bedminster as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-BEDM',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 3284,
#    'volume_24h': 2372,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Bedminster'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-07T15:00:00Z',
#    'custom_strike': {'Word': 'Woke'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV07',
#    'expected_expiration_time': '2025-11-07T15:00:00Z',
#    'expiration_time': '2025-11-07T15:00:00Z',
#    'expiration_value': '',
#    'last_price': 37,
#    'last_price_dollars': '0.3700',
#    'latest_expiration_time': '2025-11-07T15:00:00Z',
#    'liquidity': 1205422,
#    'liquidity_dollars': '12054.2200',
#    'market_type': 'binary',
#    'no_ask': 66,
#    'no_ask_dollars': '0.6600',
#    'no_bid': 64,
#    'no_bid_dollars': '0.6400',
#    'no_sub_title': 'Woke',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 433,
#    'open_time': '2025-10-30T20:00:00Z',
#    'previous_price': 34,
#    'previous_price_dollars': '0.3400',
#    'previous_yes_ask': 35,
#    'previous_yes_ask_dollars': '0.3500',
#    'previous_yes_bid': 31,
#    'previous_yes_bid_dollars': '0.3100',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Woke as part of America Business Forum, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the America Business Forum will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the America Business Forum will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'status': 'active',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV07-WOKE',
#    'title': 'What will Donald Trump say during America Business Forum?',
#    'volume': 492,
#    'volume_24h': 121,
#    'yes_ask': 36,
#    'yes_ask_dollars': '0.3600',
#    'yes_bid': 34,
#    'yes_bid_dollars': '0.3400',
#    'yes_sub_title': 'Woke'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-07T15:00:00Z',
#    'custom_strike': {'Word': 'Washington / White House'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV07',
#    'expected_expiration_time': '2025-11-07T15:00:00Z',
#    'expiration_time': '2025-11-07T15:00:00Z',
#    'expiration_value': '',
#    'last_price': 71,
#    'last_price_dollars': '0.7100',
#    'latest_expiration_time': '2025-11-07T15:00:00Z',
#    'liquidity': 1037761,
#    'liquidity_dollars': '10377.6100',
#    'market_type': 'binary',
#    'no_ask': 28,
#    'no_ask_dollars': '0.2800',
#    'no_bid': 26,
#    'no_bid_dollars': '0.2600',
#    'no_sub_title': 'Washington / White House',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 382,
#    'open_time': '2025-10-30T20:00:00Z',
#    'previous_price': 70,
#    'previous_price_dollars': '0.7000',
#    'previous_yes_ask': 70,
#    'previous_yes_ask_dollars': '0.7000',
#    'previous_yes_bid': 64,
#    'previous_yes_bid_dollars': '0.6400',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Washington / White House as part of America Business Forum, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the America Business Forum will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the America Business Forum will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'status': 'active',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV07-WASH',
#    'title': 'What will Donald Trump say during America Business Forum?',
#    'volume': 519,
#    'volume_24h': 129,
#    'yes_ask': 74,
#    'yes_ask_dollars': '0.7400',
#    'yes_bid': 72,
#    'yes_bid_dollars': '0.7200',
#    'yes_sub_title': 'Washington / White House'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-07T15:00:00Z',
#    'custom_strike': {'Word': 'Trump'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV07',
#    'expected_expiration_time': '2025-11-07T15:00:00Z',
#    'expiration_time': '2025-11-07T15:00:00Z',
#    'expiration_value': '',
#    'last_price': 70,
#    'last_price_dollars': '0.7000',
#    'latest_expiration_time': '2025-11-07T15:00:00Z',
#    'liquidity': 1125665,
#    'liquidity_dollars': '11256.6500',
#    'market_type': 'binary',
#    'no_ask': 38,
#    'no_ask_dollars': '0.3800',
#    'no_bid': 31,
#    'no_bid_dollars': '0.3100',
#    'no_sub_title': 'Trump',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 985,
#    'open_time': '2025-10-30T20:00:00Z',
#    'previous_price': 58,
#    'previous_price_dollars': '0.5800',
#    'previous_yes_ask': 59,
#    'previous_yes_ask_dollars': '0.5900',
#    'previous_yes_bid': 52,
#    'previous_yes_bid_dollars': '0.5200',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Trump as part of America Business Forum, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the America Business Forum will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the America Business Forum will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'status': 'active',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV07-TRUM',
#    'title': 'What will Donald Trump say during America Business Forum?',
#    'volume': 1030,
#    'volume_24h': 282,
#    'yes_ask': 69,
#    'yes_ask_dollars': '0.6900',
#    'yes_bid': 62,
#    'yes_bid_dollars': '0.6200',
# ...
#    'volume': 36835,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Tariff'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-10-27T14:00:00Z',
#    'custom_strike': {'Word': 'Shutdown / Shut Down'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25OCT27',
#    'expected_expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 1,
#    'last_price_dollars': '0.0100',
#    'latest_expiration_time': '2025-10-27T14:00:00Z',
#    'liquidity': 1848,
#    'liquidity_dollars': '18.4800',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Shutdown / Shut Down',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 3350,
#    'open_time': '2025-10-24T16:00:00Z',
#    'previous_price': 1,
#    'previous_price_dollars': '0.0100',
#    'previous_yes_ask': 100,
#    'previous_yes_ask_dollars': '1.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Shutdown / Shut Down as part of Bilateral Meeting and signing with the Prime Minister of Malaysia, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25OCT27-SHUT',
#    'title': 'What will Donald Trump say during Bilateral Meeting and signing with the Prime Minister of Malaysia?',
#    'volume': 4523,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Shutdown / Shut Down'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-10-27T14:00:00Z',
#    'custom_strike': {'Word': 'Sanction'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25OCT27',
#    'expected_expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 1,
#    'last_price_dollars': '0.0100',
#    'latest_expiration_time': '2025-10-27T14:00:00Z',
#    'liquidity': 11822,
#    'liquidity_dollars': '118.2200',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Sanction',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 1684,
#    'open_time': '2025-10-24T16:00:00Z',
#    'previous_price': 1,
#    'previous_price_dollars': '0.0100',
#    'previous_yes_ask': 100,
#    'previous_yes_ask_dollars': '1.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Sanction as part of Bilateral Meeting and signing with the Prime Minister of Malaysia, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25OCT27-SANC',
#    'title': 'What will Donald Trump say during Bilateral Meeting and signing with the Prime Minister of Malaysia?',
#    'volume': 2004,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Sanction'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-10-27T14:00:00Z',
#    'custom_strike': {'Word': 'Russia'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25OCT27',
#    'expected_expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 1,
#    'last_price_dollars': '0.0100',
#    'latest_expiration_time': '2025-10-27T14:00:00Z',
#    'liquidity': 7300,
#    'liquidity_dollars': '73.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Russia',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 4429,
#    'open_time': '2025-10-24T16:00:00Z',
#    'previous_price': 1,
#    'previous_price_dollars': '0.0100',
#    'previous_yes_ask': 100,
#    'previous_yes_ask_dollars': '1.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Russia as part of Bilateral Meeting and signing with the Prime Minister of Malaysia, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25OCT27-RUSS',
#    'title': 'What will Donald Trump say during Bilateral Meeting and signing with the Prime Minister of Malaysia?',
#    'volume': 5185,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Russia'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-10-27T14:00:00Z',
#    'custom_strike': {'Word': 'Rare Earth / Mineral'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25OCT27',
#    'expected_expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 1,
#    'last_price_dollars': '0.0100',
#    'latest_expiration_time': '2025-10-27T14:00:00Z',
#    'liquidity': 19620,
#    'liquidity_dollars': '196.2000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Rare Earth / Mineral',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 16359,
#    'open_time': '2025-10-24T16:00:00Z',
#    'previous_price': 1,
#    'previous_price_dollars': '0.0100',
#    'previous_yes_ask': 100,
#    'previous_yes_ask_dollars': '1.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Rare Earth / Mineral as part of Bilateral Meeting and signing with the Prime Minister of Malaysia, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25OCT27-RARE',
#    'title': 'What will Donald Trump say during Bilateral Meeting and signing with the Prime Minister of Malaysia?',
#    'volume': 22582,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Rare Earth / Mineral'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-10-27T14:00:00Z',
#    'custom_strike': {'Word': 'Putin'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25OCT27',
#    'expected_expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 1,
#    'last_price_dollars': '0.0100',
#    'latest_expiration_time': '2025-10-27T14:00:00Z',
#    'liquidity': 1719,
#    'liquidity_dollars': '17.1900',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Putin',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 1164,
#    'open_time': '2025-10-24T16:00:00Z',
#    'previous_price': 1,
#    'previous_price_dollars': '0.0100',
#    'previous_yes_ask': 100,
#    'previous_yes_ask_dollars': '1.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Putin as part of Bilateral Meeting and signing with the Prime Minister of Malaysia, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25OCT27-PUTI',
#    'title': 'What will Donald Trump say during Bilateral Meeting and signing with the Prime Minister of Malaysia?',
#    'volume': 1692,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Putin'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-10-27T14:00:00Z',
#    'custom_strike': {'Word': 'Oil'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25OCT27',
#    'expected_expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 2,
#    'last_price_dollars': '0.0200',
#    'latest_expiration_time': '2025-10-27T14:00:00Z',
#    'liquidity': 5280,
#    'liquidity_dollars': '52.8000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Oil',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 4209,
#    'open_time': '2025-10-24T16:00:00Z',
#    'previous_price': 2,
#    'previous_price_dollars': '0.0200',
#    'previous_yes_ask': 100,
#    'previous_yes_ask_dollars': '1.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Oil as part of Bilateral Meeting and signing with the Prime Minister of Malaysia, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25OCT27-OIL',
#    'title': 'What will Donald Trump say during Bilateral Meeting and signing with the Prime Minister of Malaysia?',
#    'volume': 4980,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Oil'}]}

# %%
api.get_positions()
# Out:
# {'cursor': '',
#  'event_positions': [{'event_exposure': 4706,
#    'event_exposure_dollars': '47.0696',
#    'event_ticker': 'KXUSTESTSMATH-26',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 13,
#    'realized_pnl_dollars': '0.1396',
#    'resting_order_count': 1147,
#    'total_cost': 4893,
#    'total_cost_dollars': '48.9300'},
#   {'event_exposure': 17000,
#    'event_exposure_dollars': '170.0000',
#    'event_ticker': 'KXFEDCHAIRNOM-29',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 33121,
#    'realized_pnl_dollars': '331.2100',
#    'resting_order_count': 0,
#    'total_cost': 278479,
#    'total_cost_dollars': '2784.7900'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXLARGECUT-25',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_order_count': 0,
#    'total_cost': 12100,
#    'total_cost_dollars': '121.0000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXGPTCOST-26',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': -861,
#    'realized_pnl_dollars': '-8.6100',
#    'resting_order_count': 0,
#    'total_cost': 13161,
#    'total_cost_dollars': '131.6100'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXFTACOUNTRIES-26',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 12300,
#    'realized_pnl_dollars': '123.0000',
#    'resting_order_count': 0,
#    'total_cost': 92700,
#    'total_cost_dollars': '927.0000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXPRESNOMFEDCHAIR-25',
#    'fees_paid': 723,
#    'fees_paid_dollars': '7.2300',
#    'realized_pnl': -2781,
#    'realized_pnl_dollars': '-27.8100',
#    'resting_order_count': 0,
#    'total_cost': 56481,
#    'total_cost_dollars': '564.8100'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXPLAGUECOUNT-25',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_order_count': 0,
#    'total_cost': 0,
#    'total_cost_dollars': '0.0000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXNEWPARTYMUSK',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 350,
#    'realized_pnl_dollars': '3.5000',
#    'resting_order_count': 0,
#    'total_cost': 34650,
#    'total_cost_dollars': '346.5000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'LEAVEPOWELL-25',
#    'fees_paid': 607,
#    'fees_paid_dollars': '6.0700',
#    'realized_pnl': -3100,
#    'realized_pnl_dollars': '-31.0000',
#    'resting_order_count': 0,
#    'total_cost': 83100,
#    'total_cost_dollars': '831.0000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXTARIFFEUALC-25',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_order_count': 0,
#    'total_cost': 0,
#    'total_cost_dollars': '0.0000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'RECSSNBER-25',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_order_count': 0,
#    'total_cost': 0,
#    'total_cost_dollars': '0.0000'},
#   {'event_exposure': 20700,
#    'event_exposure_dollars': '207.0000',
#    'event_ticker': 'KXGREENIND-26',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_order_count': 0,
#    'total_cost': 20700,
#    'total_cost_dollars': '207.0000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXH5N1CASES-25',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_order_count': 0,
#    'total_cost': 0,
#    'total_cost_dollars': '0.0000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXNYSECIRCUIT-26',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_order_count': 0,
#    'total_cost': 0,
#    'total_cost_dollars': '0.0000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXPRCBTC-26',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_order_count': 0,
#    'total_cost': 0,
#    'total_cost_dollars': '0.0000'}],
#  'market_positions': [{'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-09T14:42:01.980277Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 1000,
#    'ticker': 'KXUSTESTSMATH-26-NSD',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-10-30T04:21:39.253278Z',
#    'market_exposure': 4706,
#    'market_exposure_dollars': '47.0696',
#    'position': 147,
#    'realized_pnl': 13,
#    'realized_pnl_dollars': '0.1396',
#    'resting_orders_count': 147,
#    'ticker': 'KXUSTESTSMATH-26-SI',
#    'total_traded': 4893,
#    'total_traded_dollars': '48.9300'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-19T18:06:57.975762Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 551,
#    'realized_pnl_dollars': '5.5100',
#    'resting_orders_count': 0,
#    'ticker': 'KXFEDCHAIRNOM-29-KW',
#    'total_traded': 89449,
#    'total_traded_dollars': '894.4900'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-09-11T18:53:05.852646Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 9466,
#    'realized_pnl_dollars': '94.6600',
#    'resting_orders_count': 0,
#    'ticker': 'KXFEDCHAIRNOM-29-KH',
#    'total_traded': 30534,
#    'total_traded_dollars': '305.3400'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-20T12:03:28.362366Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 18104,
#    'realized_pnl_dollars': '181.0400',
#    'resting_orders_count': 0,
#    'ticker': 'KXFEDCHAIRNOM-29-CWAL',
#    'total_traded': 46496,
#    'total_traded_dollars': '464.9600'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-19T18:10:21.076063Z',
#    'market_exposure': 9000,
#    'market_exposure_dollars': '90.0000',
#    'position': 1000,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFEDCHAIRNOM-29-DZER',
#    'total_traded': 9000,
#    'total_traded_dollars': '90.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-14T19:47:40.582605Z',
#    'market_exposure': 6000,
#    'market_exposure_dollars': '60.0000',
#    'position': 1000,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFEDCHAIRNOM-29-JBUL',
#    'total_traded': 6000,
#    'total_traded_dollars': '60.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-18T16:07:27.006032Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 5000,
#    'realized_pnl_dollars': '50.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFEDCHAIRNOM-29-MBOW',
#    'total_traded': 95000,
#    'total_traded_dollars': '950.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-14T15:43:24.839958Z',
#    'market_exposure': 1000,
#    'market_exposure_dollars': '10.0000',
#    'position': 1000,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFEDCHAIRNOM-29-PJEF',
#    'total_traded': 1000,
#    'total_traded_dollars': '10.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-14T15:44:07.099083Z',
#    'market_exposure': 1000,
#    'market_exposure_dollars': '10.0000',
#    'position': 1000,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFEDCHAIRNOM-29-LLOG',
#    'total_traded': 1000,
#    'total_traded_dollars': '10.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-12T04:17:05.879394Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXLARGECUT-25',
#    'total_traded': 12100,
#    'total_traded_dollars': '121.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-07T04:52:48.819789Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': -861,
#    'realized_pnl_dollars': '-8.6100',
#    'resting_orders_count': 0,
#    'ticker': 'KXGPTCOST-26',
#    'total_traded': 13161,
#    'total_traded_dollars': '131.6100'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-19T00:19:43.122659Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFTACOUNTRIES-26-AU',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-19T00:19:02.042172Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFTACOUNTRIES-26-BR',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-16T14:19:54.133274Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFTACOUNTRIES-26-KR',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-19T00:20:06.922756Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFTACOUNTRIES-26-SA',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-19T00:21:07.802215Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFTACOUNTRIES-26-JP',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-21T14:16:07.537169Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 9600,
#    'realized_pnl_dollars': '96.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFTACOUNTRIES-26-INDO',
#    'total_traded': 65400,
#    'total_traded_dollars': '654.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-17T15:29:47.955503Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFTACOUNTRIES-26-AR',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-20T15:22:41.33229Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 2700,
#    'realized_pnl_dollars': '27.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFTACOUNTRIES-26-IN',
#    'total_traded': 27300,
#    'total_traded_dollars': '273.0000'},
#   {'fees_paid': 723,
#    'fees_paid_dollars': '7.2300',
#    'last_updated_ts': '2025-07-19T05:12:29.912922Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': -2781,
#    'realized_pnl_dollars': '-27.8100',
#    'resting_orders_count': 0,
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'total_traded': 56481,
#    'total_traded_dollars': '564.8100'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-19T05:01:05.552557Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXPLAGUECOUNT-25-5',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-17T03:00:16.865583Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 350,
#    'realized_pnl_dollars': '3.5000',
#    'resting_orders_count': 0,
#    'ticker': 'KXNEWPARTYMUSK-26',
#    'total_traded': 34650,
#    'total_traded_dollars': '346.5000'},
#   {'fees_paid': 607,
#    'fees_paid_dollars': '6.0700',
#    'last_updated_ts': '2025-07-16T01:59:09.563045Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': -3100,
#    'realized_pnl_dollars': '-31.0000',
#    'resting_orders_count': 0,
#    'ticker': 'LEAVEPOWELL-25-DEC31',
#    'total_traded': 83100,
#    'total_traded_dollars': '831.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-10T16:19:03.744923Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXTARIFFEUALC-25-DEC01',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-04-09T02:38:32.208047Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'RECSSNBER-25',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-02-07T02:49:13.021969Z',
#    'market_exposure': 20700,
#    'market_exposure_dollars': '207.0000',
#    'position': -300,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXGREENIND-26',
#    'total_traded': 20700,
#    'total_traded_dollars': '207.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2024-12-28T23:36:14.489696Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXH5N1CASES-25-50',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2024-12-22T04:59:59.079866Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXNYSECIRCUIT-26',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2024-12-16T17:26:16.22644Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXPRCBTC-26',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'}]}

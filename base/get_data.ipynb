# %%
import os
from dotenv import load_dotenv
from cryptography.hazmat.primitives import serialization
import asyncio
import nest_asyncio
import pandas as pd
import pytz
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
from base.clients.clients import KalshiHttpClient, Environment
import re
from time import sleep
import matplotlib.pyplot as plt
nest_asyncio.apply()


load_dotenv()
env = Environment.PROD
KEYID = os.getenv('KEYID') 
KEYFILE = os.getenv('KEYFILE')
try:
    with open(KEYFILE, "rb") as key_file:
        private_key = serialization.load_pem_private_key(
            key_file.read(),
            password=None  
        )
except FileNotFoundError:
    raise FileNotFoundError(f"Private key file not found at {KEYFILE}")
except Exception as e:
    raise Exception(f"Error loading private key: {str(e)}")

api = KalshiHttpClient(
    key_id=KEYID,
    private_key=private_key,
    environment=env
)

balance = api.get_balance()
print("Balance:", balance)


api.get_exchange_status()['trading_active']
# Out:
# Balance: {'balance': 175662, 'portfolio_value': 39133, 'updated_ts': 1762301834}
# True

# %%
api.plot_market_candlesticks(ticker="KXPRESNOMFEDCHAIR-25", chart_type="candlestick", days=180)

# %%
api.get_trades('KXPRESNOMFEDCHAIR-25')
# Out:
# {'cursor': 'EhIKEOYMdU7mznd7mR3fKtLu2XAaDAip9JfIBhCw7syjAw',
#  'trades': [{'count': 2,
#    'created_time': '2025-11-04T21:45:00.390246Z',
#    'no_price': 42,
#    'no_price_dollars': '0.4200',
#    'price': 0.58,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '311b252f-dd5d-485e-1c05-9decd7d0bc16',
#    'yes_price': 58,
#    'yes_price_dollars': '0.5800'},
#   {'count': 11,
#    'created_time': '2025-11-04T20:50:06.846774Z',
#    'no_price': 42,
#    'no_price_dollars': '0.4200',
#    'price': 0.58,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'f5f70fbd-ddfd-5c72-d970-794d9199ff7a',
#    'yes_price': 58,
#    'yes_price_dollars': '0.5800'},
#   {'count': 5,
#    'created_time': '2025-11-04T17:27:48.045887Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'c3da020b-67ae-4b41-a8bc-00476f5528a9',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 11,
#    'created_time': '2025-11-04T16:18:54.209396Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'ff3ebaaf-4e7e-69d1-2707-4c225a353eb0',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 10,
#    'created_time': '2025-11-04T08:26:04.988853Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'fa5e0274-adcb-441c-e5bf-da620a618fe0',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 4,
#    'created_time': '2025-11-04T07:37:31.536959Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'f87ad9b6-8d6b-7060-d8d2-df77cb9edb90',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 2,
#    'created_time': '2025-11-04T07:36:05.828622Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'e6274f34-82f3-73f8-6f79-225f766327cc',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 2,
#    'created_time': '2025-11-04T04:33:00.626202Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '581353ac-9e53-48e8-3422-1f1ded966118',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 23,
#    'created_time': '2025-11-04T02:46:29.092665Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'b2a6fdc8-6e8c-708e-71a9-919ceeabca1e',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 50,
#    'created_time': '2025-11-04T02:46:29.092665Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '8c5a71f2-e09c-7b8f-5826-fa1b08915903',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 27,
#    'created_time': '2025-11-04T02:46:29.092665Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '49990ade-9f46-7f73-643f-a78f632efe6f',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 60,
#    'created_time': '2025-11-04T02:46:29.092665Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '03d07785-a90e-7fd8-5dd5-4efeff320fb4',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 23,
#    'created_time': '2025-11-04T02:09:02.660362Z',
#    'no_price': 42,
#    'no_price_dollars': '0.4200',
#    'price': 0.58,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'af4899e2-f765-51da-a8ba-5eb820515832',
#    'yes_price': 58,
#    'yes_price_dollars': '0.5800'},
#   {'count': 1,
#    'created_time': '2025-11-03T23:49:25.065778Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'd7832117-207a-45ef-87c3-ac6d5a22496d',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 50,
#    'created_time': '2025-11-03T23:49:25.065778Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '41596bb2-80ec-4d54-82c5-12efb5d9d602',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 7,
#    'created_time': '2025-11-03T23:49:25.065778Z',
#    'no_price': 42,
#    'no_price_dollars': '0.4200',
#    'price': 0.58,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '06cbc2f8-2031-486a-893d-9ddb05016d5a',
#    'yes_price': 58,
#    'yes_price_dollars': '0.5800'},
#   {'count': 4,
#    'created_time': '2025-11-03T23:03:44.694362Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'd999484b-6020-43e6-0567-33fa21700e86',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 3,
#    'created_time': '2025-11-03T23:03:44.694362Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'c8cbb3b6-0dac-4c07-2889-a2028c507cd9',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 3,
#    'created_time': '2025-11-03T23:03:44.694362Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'b2e845a5-f0c9-4a1b-299c-6761756bf260',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 2,
#    'created_time': '2025-11-03T23:03:44.694362Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'a58ea3e6-32fb-412d-2faa-e124141a6796',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 5,
#    'created_time': '2025-11-03T23:03:44.694362Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'a4238fb4-91a3-47f4-28f3-f468b56b6827',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 4,
#    'created_time': '2025-11-03T23:03:44.694362Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '55d6f227-e77f-4ace-11b8-e0fb29f00704',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 1,
#    'created_time': '2025-11-03T21:24:45.44142Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '4f4ae35d-2b08-4b1b-dbf0-9eb15ae0bf3a',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 216,
#    'created_time': '2025-11-03T21:24:45.44142Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '48f13478-3a9f-4ba7-e488-39b24d4fa6ba',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 142,
#    'created_time': '2025-11-03T21:24:45.44142Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '3f8ba464-7524-4a83-cfc8-3abf58cf448d',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 1,
#    'created_time': '2025-11-03T21:24:45.44142Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '331b0647-405c-4258-c747-4cba495fe0f1',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 96,
#    'created_time': '2025-11-03T21:24:45.44142Z',
#    'no_price': 42,
#    'no_price_dollars': '0.4200',
#    'price': 0.58,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '1a869b57-4105-4956-e6d4-6a9e4ee9704a',
#    'yes_price': 58,
#    'yes_price_dollars': '0.5800'},
#   {'count': 22,
#    'created_time': '2025-11-03T20:36:20.522704Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'e5d84e57-de58-4b61-133d-71383f65760d',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 8,
#    'created_time': '2025-11-03T20:36:20.522704Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'ddeefbb6-c5b3-4fd5-0e19-11b3f9e31fe6',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 156,
#    'created_time': '2025-11-03T20:36:20.522704Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '6852898a-26ba-41ae-2a07-9f660af8151d',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 260,
#    'created_time': '2025-11-03T20:25:06.180941Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '5766ae81-4cf8-5b1b-f2bc-c5b9384be739',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 500,
#    'created_time': '2025-11-03T20:16:11.913001Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '4c0771ae-81ac-5c77-a5ce-7572a921ab9d',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 44,
#    'created_time': '2025-11-03T19:39:55.049748Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '52e3125a-54ca-5072-7c4c-a9faaf3497d5',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 59,
#    'created_time': '2025-11-03T18:59:39.335536Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '45504e65-33a8-5867-3b44-f36494cf6e81',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 11,
#    'created_time': '2025-11-03T16:48:55.364517Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '83b1d8f7-89e4-4b17-edda-a87579e3e289',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 2,
#    'created_time': '2025-11-03T13:23:44.98714Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'edfe6913-010c-4493-7ec0-2cc67191bf4d',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 4,
#    'created_time': '2025-11-03T10:32:37.000831Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '8afc2af2-3cc0-4947-fb15-12809dfdeffd',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 271,
#    'created_time': '2025-11-03T10:01:54.943305Z',
#    'no_price': 38,
#    'no_price_dollars': '0.3800',
#    'price': 0.62,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'e9c8a6b6-1670-6e8c-a7ac-d96d30eb4d43',
#    'yes_price': 62,
#    'yes_price_dollars': '0.6200'},
#   {'count': 15,
#    'created_time': '2025-11-03T10:01:54.943305Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'c9ec48ff-d657-6a5f-b94f-8140f4f6f9a3',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 7,
#    'created_time': '2025-11-03T09:44:27.02619Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '71931081-5f0f-401d-2a12-444db99b2f83',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 22,
#    'created_time': '2025-11-03T09:43:50.161948Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '96cef7c4-6ea0-50e3-aad8-ab7aa8717cf9',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 1,
#    'created_time': '2025-11-03T09:43:50.161948Z',
#    'no_price': 41,
#    'no_price_dollars': '0.4100',
#    'price': 0.59,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '4458a870-ad1b-5e3e-a4ed-0a17a6a4149f',
#    'yes_price': 59,
#    'yes_price_dollars': '0.5900'},
#   {'count': 20,
#    'created_time': '2025-11-03T06:33:32.815683Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'd65541a2-c013-7edc-1bb9-e6fa463803ce',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 11,
#    'created_time': '2025-11-03T06:33:32.815683Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '05d82d08-de15-75c5-2a0d-96c406c7c86c',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 20,
#    'created_time': '2025-11-03T00:50:52.192102Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '8255fafc-15fe-4e40-19e0-d3e6285c940f',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 100,
#    'created_time': '2025-11-03T00:50:47.260563Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '39706f59-10e2-74a8-ce6b-f690ee6dd59b',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 63,
#    'created_time': '2025-11-02T23:32:08.89682Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'f4dd44c3-bb7e-6bf5-cc8a-aec61afb47ad',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 880,
#    'created_time': '2025-11-02T23:32:08.89682Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'd85e740c-2c5e-6304-d6e6-058dd8fbd4cf',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 1,
#    'created_time': '2025-11-02T23:32:08.89682Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'ce7581f4-eec9-6d2c-efbd-68a47346886d',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 8,
#    'created_time': '2025-11-02T23:32:08.89682Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '9b91a5b2-1ec6-668c-de43-a428d85293d6',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 47,
#    'created_time': '2025-11-02T23:32:08.89682Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '86b8b9ff-d440-6ed8-f915-1688d4599df1',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 500,
#    'created_time': '2025-11-02T23:32:08.89682Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '1b478089-9f5c-6347-d56f-20b0a9980812',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 1,
#    'created_time': '2025-11-02T23:32:08.89682Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '152d5ca2-70a5-68d4-ceb5-dcf62b0ac06e',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 77,
#    'created_time': '2025-11-02T23:31:22.063188Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'f9332db3-374a-6a79-a7f5-84490f3259a9',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 7,
#    'created_time': '2025-11-02T21:51:07.421177Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '97aad844-14f5-69bc-627e-d3fb6c63dca5',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 49,
#    'created_time': '2025-11-02T18:32:08.237956Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '28d2c7be-96a0-5d34-39d4-83d4e37349c7',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 24,
#    'created_time': '2025-11-02T17:44:18.898735Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '7b448d95-166f-4ba7-af17-6c0ec959f55a',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 19,
#    'created_time': '2025-11-02T13:31:36.668329Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'acf7912d-efb7-4a3b-f41d-bab8d4a724ba',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 31,
#    'created_time': '2025-11-02T13:31:36.668329Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '1bf89a99-6fb6-4e6d-f801-618e38641abe',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 12,
#    'created_time': '2025-11-02T11:35:54.410152Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '9d2f73bf-1f1e-7ec1-6cbf-3cd73c48357a',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 1,
#    'created_time': '2025-11-02T06:12:39.479585Z',
#    'no_price': 38,
#    'no_price_dollars': '0.3800',
#    'price': 0.62,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '0fbd8074-5ca4-4d94-cf05-42d99fd7b94f',
#    'yes_price': 62,
#    'yes_price_dollars': '0.6200'},
#   {'count': 1,
#    'created_time': '2025-11-02T04:27:30.757033Z',
#    'no_price': 38,
#    'no_price_dollars': '0.3800',
#    'price': 0.62,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '44d67921-2734-7738-8743-54b79d1e80ef',
#    'yes_price': 62,
#    'yes_price_dollars': '0.6200'},
#   {'count': 137,
#    'created_time': '2025-11-02T03:00:22.127019Z',
#    'no_price': 38,
#    'no_price_dollars': '0.3800',
#    'price': 0.62,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '4e2e6aa9-4e2c-4008-ab66-141db8a0a38f',
#    'yes_price': 62,
#    'yes_price_dollars': '0.6200'},
#   {'count': 25,
#    'created_time': '2025-11-02T02:51:12.314886Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'b3bd7165-7456-5c89-ee96-687b67a632d2',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 132,
#    'created_time': '2025-11-02T00:02:41.935099Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '84d3aff8-e4d2-5bfd-2e8b-218b46bbe69a',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 2,
#    'created_time': '2025-11-01T23:54:45.861511Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'b9ee354d-04b4-7ddc-ebdd-1305d0ee19c9',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 458,
#    'created_time': '2025-11-01T23:38:53.329086Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '2c4ea65d-cc74-4870-519c-92cb899fa221',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 92,
#    'created_time': '2025-11-01T22:44:32.284815Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'c130466e-0ec6-5f54-322b-f3a3d81c178e',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 1000,
#    'created_time': '2025-11-01T22:44:32.284815Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '1fad3ca0-e300-54a4-30be-df1c3d4ae723',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 10,
#    'created_time': '2025-11-01T22:11:17.048659Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'c57254d6-8c94-5adc-9a33-22fcfe396665',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 47,
#    'created_time': '2025-11-01T20:52:11.199602Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '67d5515d-5f38-4490-1134-47df090d3791',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 7,
#    'created_time': '2025-11-01T20:13:13.882726Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '7cfd9b45-18f8-5d80-0db1-4b60b8c1f7d5',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 146,
#    'created_time': '2025-11-01T19:10:46.01176Z',
#    'no_price': 38,
#    'no_price_dollars': '0.3800',
#    'price': 0.62,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '7926e94c-f094-6ed4-30b8-b319b0fde97f',
#    'yes_price': 62,
#    'yes_price_dollars': '0.6200'},
#   {'count': 78,
#    'created_time': '2025-11-01T19:06:46.350971Z',
#    'no_price': 38,
#    'no_price_dollars': '0.3800',
#    'price': 0.62,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'feba22fb-2eec-5ccc-dc28-2bb2a9535673',
#    'yes_price': 62,
#    'yes_price_dollars': '0.6200'},
#   {'count': 166,
#    'created_time': '2025-11-01T18:45:34.08472Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'f3a746be-abe0-5ceb-f173-a54b2a91d9ea',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 33,
#    'created_time': '2025-11-01T18:45:34.08472Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'dc5cc360-9a4e-5845-e1b3-4e923087523a',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 29,
#    'created_time': '2025-11-01T18:45:22.539752Z',
#    'no_price': 38,
#    'no_price_dollars': '0.3800',
#    'price': 0.62,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '56d23f43-96e4-4614-c5a2-d9925752958f',
#    'yes_price': 62,
#    'yes_price_dollars': '0.6200'},
#   {'count': 267,
#    'created_time': '2025-11-01T18:45:18.492317Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'cfc5ab32-c025-6db3-5098-8de408e8b409',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 4,
#    'created_time': '2025-11-01T18:45:18.492317Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'b2c526be-8e52-6198-6d99-6ffd84b2a22f',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 8,
#    'created_time': '2025-11-01T18:45:18.492317Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '82eef074-294e-63b3-4e57-83740ff95a36',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 429,
#    'created_time': '2025-11-01T18:45:18.492317Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '5b7f98e4-7450-6ca4-5c95-c3f384cda431',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 1000,
#    'created_time': '2025-11-01T18:45:18.492317Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '41262ec4-a1f3-6dae-4d2f-91b342dc1ea2',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 93,
#    'created_time': '2025-11-01T18:45:18.492317Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '2e17cede-eec8-669c-790b-388c07831826',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 14,
#    'created_time': '2025-11-01T18:45:18.492317Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '1e3e90e9-1afd-6f7c-4847-7c7a964a6ae3',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 2,
#    'created_time': '2025-11-01T18:45:18.492317Z',
#    'no_price': 40,
#    'no_price_dollars': '0.4000',
#    'price': 0.6,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '07a093f2-e635-6df0-59c7-7bfffff1536c',
#    'yes_price': 60,
#    'yes_price_dollars': '0.6000'},
#   {'count': 61,
#    'created_time': '2025-11-01T16:37:57.640666Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '4fb1006f-0595-5495-0f22-8e3a0a783590',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 32,
#    'created_time': '2025-11-01T15:52:11.127244Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'e879d37b-e66e-64a6-2211-26d8e7345bbe',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 68,
#    'created_time': '2025-11-01T15:52:11.127244Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '39d2a58a-b20b-6193-1b13-234c1ece2761',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 221,
#    'created_time': '2025-11-01T15:01:27.025951Z',
#    'no_price': 38,
#    'no_price_dollars': '0.3800',
#    'price': 0.62,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'f2a0a8d2-2bf0-51d8-a897-aa18616176e3',
#    'yes_price': 62,
#    'yes_price_dollars': '0.6200'},
#   {'count': 24,
#    'created_time': '2025-11-01T14:06:22.178488Z',
#    'no_price': 39,
#    'no_price_dollars': '0.3900',
#    'price': 0.61,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '0b5192a7-ee51-579a-1e01-d49870ef22f5',
#    'yes_price': 61,
#    'yes_price_dollars': '0.6100'},
#   {'count': 6,
#    'created_time': '2025-11-01T13:40:54.900038Z',
#    'no_price': 38,
#    'no_price_dollars': '0.3800',
#    'price': 0.62,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'e75653d8-8b4a-5e17-2eda-c86d3e8657a2',
#    'yes_price': 62,
#    'yes_price_dollars': '0.6200'},
#   {'count': 250,
#    'created_time': '2025-11-01T13:40:54.900038Z',
#    'no_price': 38,
#    'no_price_dollars': '0.3800',
#    'price': 0.62,
#    'taker_side': 'no',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '846cb4f0-b2e2-5c39-0748-710775262bac',
#    'yes_price': 62,
#    'yes_price_dollars': '0.6200'},
#   {'count': 32,
#    'created_time': '2025-11-01T13:08:46.884759Z',
#    'no_price': 38,
#    'no_price_dollars': '0.3800',
#    'price': 0.62,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'e2940786-f5ad-50c1-86e3-36d9497755e9',
#    'yes_price': 62,
#    'yes_price_dollars': '0.6200'},
#   {'count': 36,
#    'created_time': '2025-11-01T13:08:46.884759Z',
#    'no_price': 37,
#    'no_price_dollars': '0.3700',
#    'price': 0.63,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'c7cec167-85d6-5952-86e0-f4e31b16d001',
#    'yes_price': 63,
#    'yes_price_dollars': '0.6300'},
#   {'count': 3,
#    'created_time': '2025-11-01T13:08:46.884759Z',
#    'no_price': 37,
#    'no_price_dollars': '0.3700',
#    'price': 0.63,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'bc22d4df-3645-593b-bab9-6c7b5246e77f',
#    'yes_price': 63,
#    'yes_price_dollars': '0.6300'},
#   {'count': 32,
#    'created_time': '2025-11-01T13:08:46.884759Z',
#    'no_price': 37,
#    'no_price_dollars': '0.3700',
#    'price': 0.63,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '80b1e4f2-4176-577c-8272-e07ded0b43f0',
#    'yes_price': 63,
#    'yes_price_dollars': '0.6300'},
#   {'count': 9,
#    'created_time': '2025-11-01T13:08:46.884759Z',
#    'no_price': 38,
#    'no_price_dollars': '0.3800',
#    'price': 0.62,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '7dad9bc7-f8ca-5e03-bce5-c735af620354',
#    'yes_price': 62,
#    'yes_price_dollars': '0.6200'},
#   {'count': 25,
#    'created_time': '2025-11-01T13:08:46.884759Z',
#    'no_price': 38,
#    'no_price_dollars': '0.3800',
#    'price': 0.62,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '31842764-c047-50b5-af26-c8341ead4954',
#    'yes_price': 62,
#    'yes_price_dollars': '0.6200'},
#   {'count': 863,
#    'created_time': '2025-11-01T13:08:46.884759Z',
#    'no_price': 37,
#    'no_price_dollars': '0.3700',
#    'price': 0.63,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': '17406ee9-3ab4-5ebf-ac52-5d741bba0114',
#    'yes_price': 63,
#    'yes_price_dollars': '0.6300'},
#   {'count': 15,
#    'created_time': '2025-11-01T12:16:41.879966Z',
#    'no_price': 38,
#    'no_price_dollars': '0.3800',
#    'price': 0.62,
#    'taker_side': 'yes',
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'trade_id': 'e60c754e-e6ce-777b-991d-df2ad2eed970',
#    'yes_price': 62,
#    'yes_price_dollars': '0.6200'}]}

# %%
api.get_markets(series_ticker='KXTRUMPMENTION')
# Out:
# {'cursor': 'CgsIl6HuxwYQsKyJIBIaS1hUUlVNUE1FTlRJT04tMjVPQ1QyNy1PSUw',
#  'markets': [{'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Windmill'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 98,
#    'last_price_dollars': '0.9800',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Windmill',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 8636,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 34,
#    'previous_price_dollars': '0.3400',
#    'previous_yes_ask': 34,
#    'previous_yes_ask_dollars': '0.3400',
#    'previous_yes_bid': 29,
#    'previous_yes_bid_dollars': '0.2900',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Windmill as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-WIND',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 9838,
#    'volume_24h': 8617,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Windmill'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Trump'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 2,
#    'last_price_dollars': '0.0200',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Trump',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 13435,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 27,
#    'previous_price_dollars': '0.2700',
#    'previous_yes_ask': 35,
#    'previous_yes_ask_dollars': '0.3500',
#    'previous_yes_bid': 27,
#    'previous_yes_bid_dollars': '0.2700',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Trump as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-TRUM',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 16318,
#    'volume_24h': 15505,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Trump'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Tax'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 98,
#    'last_price_dollars': '0.9800',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Tax',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 7242,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 79,
#    'previous_price_dollars': '0.7900',
#    'previous_yes_ask': 85,
#    'previous_yes_ask_dollars': '0.8500',
#    'previous_yes_bid': 79,
#    'previous_yes_bid_dollars': '0.7900',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Tax as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-TAX',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 8366,
#    'volume_24h': 7052,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Tax'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Radical Left'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 98,
#    'last_price_dollars': '0.9800',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Radical Left',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 4580,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 86,
#    'previous_price_dollars': '0.8600',
#    'previous_yes_ask': 85,
#    'previous_yes_ask_dollars': '0.8500',
#    'previous_yes_bid': 56,
#    'previous_yes_bid_dollars': '0.5600',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Radical Left as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-RADI',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 5764,
#    'volume_24h': 4777,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Radical Left'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Invest / Investment'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 2,
#    'last_price_dollars': '0.0200',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Invest / Investment',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 8260,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 38,
#    'previous_price_dollars': '0.3800',
#    'previous_yes_ask': 40,
#    'previous_yes_ask_dollars': '0.4000',
#    'previous_yes_bid': 34,
#    'previous_yes_bid_dollars': '0.3400',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Invest / Investment as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-INVE',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 9033,
#    'volume_24h': 8724,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Invest / Investment'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Inflation'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 1,
#    'last_price_dollars': '0.0100',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Inflation',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 5971,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 42,
#    'previous_price_dollars': '0.4200',
#    'previous_yes_ask': 42,
#    'previous_yes_ask_dollars': '0.4200',
#    'previous_yes_bid': 34,
#    'previous_yes_bid_dollars': '0.3400',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Inflation as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-INFL',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 7808,
#    'volume_24h': 7117,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Inflation'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Illegal Alien'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 99,
#    'last_price_dollars': '0.9900',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Illegal Alien',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 7174,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 50,
#    'previous_price_dollars': '0.5000',
#    'previous_yes_ask': 59,
#    'previous_yes_ask_dollars': '0.5900',
#    'previous_yes_bid': 56,
#    'previous_yes_bid_dollars': '0.5600',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Illegal Alien as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-ILLE',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 8260,
#    'volume_24h': 7501,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Illegal Alien'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Hottest'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 2,
#    'last_price_dollars': '0.0200',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Hottest',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 3365,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 52,
#    'previous_price_dollars': '0.5200',
#    'previous_yes_ask': 52,
#    'previous_yes_ask_dollars': '0.5200',
#    'previous_yes_bid': 34,
#    'previous_yes_bid_dollars': '0.3400',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Hottest as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-HOTT',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 4437,
#    'volume_24h': 4234,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Hottest'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Energy'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 98,
#    'last_price_dollars': '0.9800',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Energy',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 4435,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 80,
#    'previous_price_dollars': '0.8000',
#    'previous_yes_ask': 83,
#    'previous_yes_ask_dollars': '0.8300',
#    'previous_yes_bid': 80,
#    'previous_yes_bid_dollars': '0.8000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Energy as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-ENER',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 5110,
#    'volume_24h': 3339,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Energy'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Drug'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 97,
#    'last_price_dollars': '0.9700',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Drug',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 8733,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 64,
#    'previous_price_dollars': '0.6400',
#    'previous_yes_ask': 65,
#    'previous_yes_ask_dollars': '0.6500',
#    'previous_yes_bid': 57,
#    'previous_yes_bid_dollars': '0.5700',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Drug as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-DRUG',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 9732,
#    'volume_24h': 8892,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Drug'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Disaster'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 97,
#    'last_price_dollars': '0.9700',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Disaster',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 5724,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 65,
#    'previous_price_dollars': '0.6500',
#    'previous_yes_ask': 64,
#    'previous_yes_ask_dollars': '0.6400',
#    'previous_yes_bid': 56,
#    'previous_yes_bid_dollars': '0.5600',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Disaster as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-DISA',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 6514,
#    'volume_24h': 6171,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Disaster'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Democrat'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 98,
#    'last_price_dollars': '0.9800',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Democrat',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 6428,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 87,
#    'previous_price_dollars': '0.8700',
#    'previous_yes_ask': 86,
#    'previous_yes_ask_dollars': '0.8600',
#    'previous_yes_bid': 78,
#    'previous_yes_bid_dollars': '0.7800',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Democrat as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-DEMO',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 8161,
#    'volume_24h': 6595,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Democrat'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Corrupt'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 98,
#    'last_price_dollars': '0.9800',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Corrupt',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 4186,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 63,
#    'previous_price_dollars': '0.6300',
#    'previous_yes_ask': 63,
#    'previous_yes_ask_dollars': '0.6300',
#    'previous_yes_bid': 55,
#    'previous_yes_bid_dollars': '0.5500',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Corrupt as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-CORR',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 6018,
#    'volume_24h': 4542,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Corrupt'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Cheat / Cheater / Cheated'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 1,
#    'last_price_dollars': '0.0100',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Cheat / Cheater / Cheated',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 27138,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 30,
#    'previous_price_dollars': '0.3000',
#    'previous_yes_ask': 33,
#    'previous_yes_ask_dollars': '0.3300',
#    'previous_yes_bid': 25,
#    'previous_yes_bid_dollars': '0.2500',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Cheat / Cheater / Cheated as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-CHEA',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 36610,
#    'volume_24h': 36132,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Cheat / Cheater / Cheated'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Border'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'Yes',
#    'last_price': 98,
#    'last_price_dollars': '0.9800',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Border',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 7456,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 70,
#    'previous_price_dollars': '0.7000',
#    'previous_yes_ask': 70,
#    'previous_yes_ask_dollars': '0.7000',
#    'previous_yes_bid': 61,
#    'previous_yes_bid_dollars': '0.6100',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'yes',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Border as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 100,
#    'settlement_value_dollars': '1.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-BORD',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 9335,
#    'volume_24h': 6471,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Border'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Biden'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 3,
#    'last_price_dollars': '0.0300',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Biden',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 30723,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 73,
#    'previous_price_dollars': '0.7300',
#    'previous_yes_ask': 75,
#    'previous_yes_ask_dollars': '0.7500',
#    'previous_yes_bid': 69,
#    'previous_yes_bid_dollars': '0.6900',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Biden as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-BIDE',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 40075,
#    'volume_24h': 39719,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Biden'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-04T15:00:00Z',
#    'custom_strike': {'Word': 'Bedminster'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV04',
#    'expected_expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_time': '2025-11-04T15:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 2,
#    'last_price_dollars': '0.0200',
#    'latest_expiration_time': '2025-11-04T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Bedminster',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 2364,
#    'open_time': '2025-11-03T06:00:00Z',
#    'previous_price': 30,
#    'previous_price_dollars': '0.3000',
#    'previous_yes_ask': 32,
#    'previous_yes_ask_dollars': '0.3200',
#    'previous_yes_bid': 22,
#    'previous_yes_bid_dollars': '0.2200',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Bedminster as part of New Jersey Tele-Rally on November 3rd, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the New Jersey Tele-Rally on November 3rd will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the New Jersey Tele-Rally on November 3rd will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV04-BEDM',
#    'title': 'What will Donald Trump say during New Jersey Tele-Rally on November 3rd?',
#    'volume': 3284,
#    'volume_24h': 2372,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Bedminster'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-07T15:00:00Z',
#    'custom_strike': {'Word': 'Woke'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV07',
#    'expected_expiration_time': '2025-11-07T15:00:00Z',
#    'expiration_time': '2025-11-07T15:00:00Z',
#    'expiration_value': '',
#    'last_price': 37,
#    'last_price_dollars': '0.3700',
#    'latest_expiration_time': '2025-11-07T15:00:00Z',
#    'liquidity': 1205422,
#    'liquidity_dollars': '12054.2200',
#    'market_type': 'binary',
#    'no_ask': 66,
#    'no_ask_dollars': '0.6600',
#    'no_bid': 64,
#    'no_bid_dollars': '0.6400',
#    'no_sub_title': 'Woke',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 433,
#    'open_time': '2025-10-30T20:00:00Z',
#    'previous_price': 34,
#    'previous_price_dollars': '0.3400',
#    'previous_yes_ask': 35,
#    'previous_yes_ask_dollars': '0.3500',
#    'previous_yes_bid': 31,
#    'previous_yes_bid_dollars': '0.3100',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Woke as part of America Business Forum, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the America Business Forum will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the America Business Forum will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'status': 'active',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV07-WOKE',
#    'title': 'What will Donald Trump say during America Business Forum?',
#    'volume': 492,
#    'volume_24h': 121,
#    'yes_ask': 36,
#    'yes_ask_dollars': '0.3600',
#    'yes_bid': 34,
#    'yes_bid_dollars': '0.3400',
#    'yes_sub_title': 'Woke'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-07T15:00:00Z',
#    'custom_strike': {'Word': 'Washington / White House'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV07',
#    'expected_expiration_time': '2025-11-07T15:00:00Z',
#    'expiration_time': '2025-11-07T15:00:00Z',
#    'expiration_value': '',
#    'last_price': 71,
#    'last_price_dollars': '0.7100',
#    'latest_expiration_time': '2025-11-07T15:00:00Z',
#    'liquidity': 1037761,
#    'liquidity_dollars': '10377.6100',
#    'market_type': 'binary',
#    'no_ask': 28,
#    'no_ask_dollars': '0.2800',
#    'no_bid': 26,
#    'no_bid_dollars': '0.2600',
#    'no_sub_title': 'Washington / White House',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 382,
#    'open_time': '2025-10-30T20:00:00Z',
#    'previous_price': 70,
#    'previous_price_dollars': '0.7000',
#    'previous_yes_ask': 70,
#    'previous_yes_ask_dollars': '0.7000',
#    'previous_yes_bid': 64,
#    'previous_yes_bid_dollars': '0.6400',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Washington / White House as part of America Business Forum, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the America Business Forum will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the America Business Forum will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'status': 'active',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV07-WASH',
#    'title': 'What will Donald Trump say during America Business Forum?',
#    'volume': 519,
#    'volume_24h': 129,
#    'yes_ask': 74,
#    'yes_ask_dollars': '0.7400',
#    'yes_bid': 72,
#    'yes_bid_dollars': '0.7200',
#    'yes_sub_title': 'Washington / White House'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-07T15:00:00Z',
#    'custom_strike': {'Word': 'Trump'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25NOV07',
#    'expected_expiration_time': '2025-11-07T15:00:00Z',
#    'expiration_time': '2025-11-07T15:00:00Z',
#    'expiration_value': '',
#    'last_price': 70,
#    'last_price_dollars': '0.7000',
#    'latest_expiration_time': '2025-11-07T15:00:00Z',
#    'liquidity': 1125665,
#    'liquidity_dollars': '11256.6500',
#    'market_type': 'binary',
#    'no_ask': 38,
#    'no_ask_dollars': '0.3800',
#    'no_bid': 31,
#    'no_bid_dollars': '0.3100',
#    'no_sub_title': 'Trump',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 985,
#    'open_time': '2025-10-30T20:00:00Z',
#    'previous_price': 58,
#    'previous_price_dollars': '0.5800',
#    'previous_yes_ask': 59,
#    'previous_yes_ask_dollars': '0.5900',
#    'previous_yes_bid': 52,
#    'previous_yes_bid_dollars': '0.5200',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Trump as part of America Business Forum, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the America Business Forum will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the America Business Forum will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'status': 'active',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25NOV07-TRUM',
#    'title': 'What will Donald Trump say during America Business Forum?',
#    'volume': 1030,
#    'volume_24h': 282,
#    'yes_ask': 69,
#    'yes_ask_dollars': '0.6900',
#    'yes_bid': 62,
#    'yes_bid_dollars': '0.6200',
# ...
#    'volume': 36835,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Tariff'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-10-27T14:00:00Z',
#    'custom_strike': {'Word': 'Shutdown / Shut Down'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25OCT27',
#    'expected_expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 1,
#    'last_price_dollars': '0.0100',
#    'latest_expiration_time': '2025-10-27T14:00:00Z',
#    'liquidity': 1848,
#    'liquidity_dollars': '18.4800',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Shutdown / Shut Down',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 3350,
#    'open_time': '2025-10-24T16:00:00Z',
#    'previous_price': 1,
#    'previous_price_dollars': '0.0100',
#    'previous_yes_ask': 100,
#    'previous_yes_ask_dollars': '1.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Shutdown / Shut Down as part of Bilateral Meeting and signing with the Prime Minister of Malaysia, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25OCT27-SHUT',
#    'title': 'What will Donald Trump say during Bilateral Meeting and signing with the Prime Minister of Malaysia?',
#    'volume': 4523,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Shutdown / Shut Down'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-10-27T14:00:00Z',
#    'custom_strike': {'Word': 'Sanction'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25OCT27',
#    'expected_expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 1,
#    'last_price_dollars': '0.0100',
#    'latest_expiration_time': '2025-10-27T14:00:00Z',
#    'liquidity': 11822,
#    'liquidity_dollars': '118.2200',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Sanction',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 1684,
#    'open_time': '2025-10-24T16:00:00Z',
#    'previous_price': 1,
#    'previous_price_dollars': '0.0100',
#    'previous_yes_ask': 100,
#    'previous_yes_ask_dollars': '1.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Sanction as part of Bilateral Meeting and signing with the Prime Minister of Malaysia, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25OCT27-SANC',
#    'title': 'What will Donald Trump say during Bilateral Meeting and signing with the Prime Minister of Malaysia?',
#    'volume': 2004,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Sanction'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-10-27T14:00:00Z',
#    'custom_strike': {'Word': 'Russia'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25OCT27',
#    'expected_expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 1,
#    'last_price_dollars': '0.0100',
#    'latest_expiration_time': '2025-10-27T14:00:00Z',
#    'liquidity': 7300,
#    'liquidity_dollars': '73.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Russia',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 4429,
#    'open_time': '2025-10-24T16:00:00Z',
#    'previous_price': 1,
#    'previous_price_dollars': '0.0100',
#    'previous_yes_ask': 100,
#    'previous_yes_ask_dollars': '1.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Russia as part of Bilateral Meeting and signing with the Prime Minister of Malaysia, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25OCT27-RUSS',
#    'title': 'What will Donald Trump say during Bilateral Meeting and signing with the Prime Minister of Malaysia?',
#    'volume': 5185,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Russia'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-10-27T14:00:00Z',
#    'custom_strike': {'Word': 'Rare Earth / Mineral'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25OCT27',
#    'expected_expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 1,
#    'last_price_dollars': '0.0100',
#    'latest_expiration_time': '2025-10-27T14:00:00Z',
#    'liquidity': 19620,
#    'liquidity_dollars': '196.2000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Rare Earth / Mineral',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 16359,
#    'open_time': '2025-10-24T16:00:00Z',
#    'previous_price': 1,
#    'previous_price_dollars': '0.0100',
#    'previous_yes_ask': 100,
#    'previous_yes_ask_dollars': '1.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Rare Earth / Mineral as part of Bilateral Meeting and signing with the Prime Minister of Malaysia, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25OCT27-RARE',
#    'title': 'What will Donald Trump say during Bilateral Meeting and signing with the Prime Minister of Malaysia?',
#    'volume': 22582,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Rare Earth / Mineral'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-10-27T14:00:00Z',
#    'custom_strike': {'Word': 'Putin'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25OCT27',
#    'expected_expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 1,
#    'last_price_dollars': '0.0100',
#    'latest_expiration_time': '2025-10-27T14:00:00Z',
#    'liquidity': 1719,
#    'liquidity_dollars': '17.1900',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Putin',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 1164,
#    'open_time': '2025-10-24T16:00:00Z',
#    'previous_price': 1,
#    'previous_price_dollars': '0.0100',
#    'previous_yes_ask': 100,
#    'previous_yes_ask_dollars': '1.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Putin as part of Bilateral Meeting and signing with the Prime Minister of Malaysia, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25OCT27-PUTI',
#    'title': 'What will Donald Trump say during Bilateral Meeting and signing with the Prime Minister of Malaysia?',
#    'volume': 1692,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Putin'},
#   {'can_close_early': True,
#    'category': '',
#    'close_time': '2025-10-27T14:00:00Z',
#    'custom_strike': {'Word': 'Oil'},
#    'early_close_condition': 'This market will close and expire early if the event occurs.',
#    'event_ticker': 'KXTRUMPMENTION-25OCT27',
#    'expected_expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_time': '2025-10-27T14:00:00Z',
#    'expiration_value': 'No',
#    'last_price': 2,
#    'last_price_dollars': '0.0200',
#    'latest_expiration_time': '2025-10-27T14:00:00Z',
#    'liquidity': 5280,
#    'liquidity_dollars': '52.8000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': 'Oil',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 4209,
#    'open_time': '2025-10-24T16:00:00Z',
#    'previous_price': 2,
#    'previous_price_dollars': '0.0200',
#    'previous_yes_ask': 100,
#    'previous_yes_ask_dollars': '1.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': 'no',
#    'risk_limit_cents': 0,
#    'rules_primary': 'If Donald Trump says Oil as part of Bilateral Meeting and signing with the Prime Minister of Malaysia, then the market resolves to Yes.',
#    'rules_secondary': 'Video of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be primarily used to resolve the market; if a consensus by Kalshi employees cannot be reached using video, transcripts of the Bilateral Meeting and signing with the Prime Minister of Malaysia will be used according to the news publications listed in the contract. The exact phrase/word, or a plural or possessive form of the phrase/word, must be used. Grammatical/tense inflections are otherwise not included. Please see full rules for more details. If this event is not opened to the press for a live televised or streamed event this market will resolve to no.',
#    'settlement_timer_seconds': 1800,
#    'settlement_value': 0,
#    'settlement_value_dollars': '0.0000',
#    'status': 'finalized',
#    'strike_type': 'custom',
#    'subtitle': '',
#    'tick_size': 1,
#    'ticker': 'KXTRUMPMENTION-25OCT27-OIL',
#    'title': 'What will Donald Trump say during Bilateral Meeting and signing with the Prime Minister of Malaysia?',
#    'volume': 4980,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': 'Oil'}]}

# %%
api.get_positions()
# Out:
# {'cursor': '',
#  'event_positions': [{'event_exposure': 4706,
#    'event_exposure_dollars': '47.0696',
#    'event_ticker': 'KXUSTESTSMATH-26',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 13,
#    'realized_pnl_dollars': '0.1396',
#    'resting_order_count': 1147,
#    'total_cost': 4893,
#    'total_cost_dollars': '48.9300'},
#   {'event_exposure': 17000,
#    'event_exposure_dollars': '170.0000',
#    'event_ticker': 'KXFEDCHAIRNOM-29',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 33121,
#    'realized_pnl_dollars': '331.2100',
#    'resting_order_count': 0,
#    'total_cost': 278479,
#    'total_cost_dollars': '2784.7900'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXLARGECUT-25',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_order_count': 0,
#    'total_cost': 12100,
#    'total_cost_dollars': '121.0000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXGPTCOST-26',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': -861,
#    'realized_pnl_dollars': '-8.6100',
#    'resting_order_count': 0,
#    'total_cost': 13161,
#    'total_cost_dollars': '131.6100'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXFTACOUNTRIES-26',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 12300,
#    'realized_pnl_dollars': '123.0000',
#    'resting_order_count': 0,
#    'total_cost': 92700,
#    'total_cost_dollars': '927.0000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXPRESNOMFEDCHAIR-25',
#    'fees_paid': 723,
#    'fees_paid_dollars': '7.2300',
#    'realized_pnl': -2781,
#    'realized_pnl_dollars': '-27.8100',
#    'resting_order_count': 0,
#    'total_cost': 56481,
#    'total_cost_dollars': '564.8100'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXPLAGUECOUNT-25',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_order_count': 0,
#    'total_cost': 0,
#    'total_cost_dollars': '0.0000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXNEWPARTYMUSK',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 350,
#    'realized_pnl_dollars': '3.5000',
#    'resting_order_count': 0,
#    'total_cost': 34650,
#    'total_cost_dollars': '346.5000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'LEAVEPOWELL-25',
#    'fees_paid': 607,
#    'fees_paid_dollars': '6.0700',
#    'realized_pnl': -3100,
#    'realized_pnl_dollars': '-31.0000',
#    'resting_order_count': 0,
#    'total_cost': 83100,
#    'total_cost_dollars': '831.0000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXTARIFFEUALC-25',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_order_count': 0,
#    'total_cost': 0,
#    'total_cost_dollars': '0.0000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'RECSSNBER-25',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_order_count': 0,
#    'total_cost': 0,
#    'total_cost_dollars': '0.0000'},
#   {'event_exposure': 20700,
#    'event_exposure_dollars': '207.0000',
#    'event_ticker': 'KXGREENIND-26',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_order_count': 0,
#    'total_cost': 20700,
#    'total_cost_dollars': '207.0000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXH5N1CASES-25',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_order_count': 0,
#    'total_cost': 0,
#    'total_cost_dollars': '0.0000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXNYSECIRCUIT-26',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_order_count': 0,
#    'total_cost': 0,
#    'total_cost_dollars': '0.0000'},
#   {'event_exposure': 0,
#    'event_exposure_dollars': '0.0000',
#    'event_ticker': 'KXPRCBTC-26',
#    'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_order_count': 0,
#    'total_cost': 0,
#    'total_cost_dollars': '0.0000'}],
#  'market_positions': [{'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-09T14:42:01.980277Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 1000,
#    'ticker': 'KXUSTESTSMATH-26-NSD',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-10-30T04:21:39.253278Z',
#    'market_exposure': 4706,
#    'market_exposure_dollars': '47.0696',
#    'position': 147,
#    'realized_pnl': 13,
#    'realized_pnl_dollars': '0.1396',
#    'resting_orders_count': 147,
#    'ticker': 'KXUSTESTSMATH-26-SI',
#    'total_traded': 4893,
#    'total_traded_dollars': '48.9300'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-19T18:06:57.975762Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 551,
#    'realized_pnl_dollars': '5.5100',
#    'resting_orders_count': 0,
#    'ticker': 'KXFEDCHAIRNOM-29-KW',
#    'total_traded': 89449,
#    'total_traded_dollars': '894.4900'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-09-11T18:53:05.852646Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 9466,
#    'realized_pnl_dollars': '94.6600',
#    'resting_orders_count': 0,
#    'ticker': 'KXFEDCHAIRNOM-29-KH',
#    'total_traded': 30534,
#    'total_traded_dollars': '305.3400'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-20T12:03:28.362366Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 18104,
#    'realized_pnl_dollars': '181.0400',
#    'resting_orders_count': 0,
#    'ticker': 'KXFEDCHAIRNOM-29-CWAL',
#    'total_traded': 46496,
#    'total_traded_dollars': '464.9600'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-19T18:10:21.076063Z',
#    'market_exposure': 9000,
#    'market_exposure_dollars': '90.0000',
#    'position': 1000,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFEDCHAIRNOM-29-DZER',
#    'total_traded': 9000,
#    'total_traded_dollars': '90.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-14T19:47:40.582605Z',
#    'market_exposure': 6000,
#    'market_exposure_dollars': '60.0000',
#    'position': 1000,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFEDCHAIRNOM-29-JBUL',
#    'total_traded': 6000,
#    'total_traded_dollars': '60.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-18T16:07:27.006032Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 5000,
#    'realized_pnl_dollars': '50.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFEDCHAIRNOM-29-MBOW',
#    'total_traded': 95000,
#    'total_traded_dollars': '950.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-14T15:43:24.839958Z',
#    'market_exposure': 1000,
#    'market_exposure_dollars': '10.0000',
#    'position': 1000,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFEDCHAIRNOM-29-PJEF',
#    'total_traded': 1000,
#    'total_traded_dollars': '10.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-14T15:44:07.099083Z',
#    'market_exposure': 1000,
#    'market_exposure_dollars': '10.0000',
#    'position': 1000,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFEDCHAIRNOM-29-LLOG',
#    'total_traded': 1000,
#    'total_traded_dollars': '10.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-12T04:17:05.879394Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXLARGECUT-25',
#    'total_traded': 12100,
#    'total_traded_dollars': '121.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-08-07T04:52:48.819789Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': -861,
#    'realized_pnl_dollars': '-8.6100',
#    'resting_orders_count': 0,
#    'ticker': 'KXGPTCOST-26',
#    'total_traded': 13161,
#    'total_traded_dollars': '131.6100'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-19T00:19:43.122659Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFTACOUNTRIES-26-AU',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-19T00:19:02.042172Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFTACOUNTRIES-26-BR',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-16T14:19:54.133274Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFTACOUNTRIES-26-KR',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-19T00:20:06.922756Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFTACOUNTRIES-26-SA',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-19T00:21:07.802215Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFTACOUNTRIES-26-JP',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-21T14:16:07.537169Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 9600,
#    'realized_pnl_dollars': '96.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFTACOUNTRIES-26-INDO',
#    'total_traded': 65400,
#    'total_traded_dollars': '654.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-17T15:29:47.955503Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFTACOUNTRIES-26-AR',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-20T15:22:41.33229Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 2700,
#    'realized_pnl_dollars': '27.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXFTACOUNTRIES-26-IN',
#    'total_traded': 27300,
#    'total_traded_dollars': '273.0000'},
#   {'fees_paid': 723,
#    'fees_paid_dollars': '7.2300',
#    'last_updated_ts': '2025-07-19T05:12:29.912922Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': -2781,
#    'realized_pnl_dollars': '-27.8100',
#    'resting_orders_count': 0,
#    'ticker': 'KXPRESNOMFEDCHAIR-25',
#    'total_traded': 56481,
#    'total_traded_dollars': '564.8100'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-19T05:01:05.552557Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXPLAGUECOUNT-25-5',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-17T03:00:16.865583Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 350,
#    'realized_pnl_dollars': '3.5000',
#    'resting_orders_count': 0,
#    'ticker': 'KXNEWPARTYMUSK-26',
#    'total_traded': 34650,
#    'total_traded_dollars': '346.5000'},
#   {'fees_paid': 607,
#    'fees_paid_dollars': '6.0700',
#    'last_updated_ts': '2025-07-16T01:59:09.563045Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': -3100,
#    'realized_pnl_dollars': '-31.0000',
#    'resting_orders_count': 0,
#    'ticker': 'LEAVEPOWELL-25-DEC31',
#    'total_traded': 83100,
#    'total_traded_dollars': '831.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-07-10T16:19:03.744923Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXTARIFFEUALC-25-DEC01',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-04-09T02:38:32.208047Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'RECSSNBER-25',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2025-02-07T02:49:13.021969Z',
#    'market_exposure': 20700,
#    'market_exposure_dollars': '207.0000',
#    'position': -300,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXGREENIND-26',
#    'total_traded': 20700,
#    'total_traded_dollars': '207.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2024-12-28T23:36:14.489696Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXH5N1CASES-25-50',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2024-12-22T04:59:59.079866Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXNYSECIRCUIT-26',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'},
#   {'fees_paid': 0,
#    'fees_paid_dollars': '0.0000',
#    'last_updated_ts': '2024-12-16T17:26:16.22644Z',
#    'market_exposure': 0,
#    'market_exposure_dollars': '0.0000',
#    'position': 0,
#    'realized_pnl': 0,
#    'realized_pnl_dollars': '0.0000',
#    'resting_orders_count': 0,
#    'ticker': 'KXPRCBTC-26',
#    'total_traded': 0,
#    'total_traded_dollars': '0.0000'}]}
